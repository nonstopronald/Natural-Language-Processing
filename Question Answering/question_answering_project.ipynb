# %% [markdown]
# ## 1. Read the data

# %%
import pandas as pd
import spacy

df = pd.read_csv("news_dataset.csv", encoding="ISO-8859-1")

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 7 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   id       1000 non-null   int64
#  1   author   994 non-null    object
#  2   date     1000 non-null   object
#  3   year     1000 non-null   object
#  4   month    1000 non-null   object
#  5   topic    1000 non-null   object
#  6   article  1000 non-null   object
# dtypes: int64(1), object(6)
# memory usage: 54.8+ KB

# %% [markdown]
# ## 2. Data preprocessing

# %%
df_clean = df.dropna(subset=['author'])

df_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 994 entries, 0 to 999
# Data columns (total 7 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   id       994 non-null    int64
#  1   author   994 non-null    object
#  2   date     994 non-null    object
#  3   year     994 non-null    object
#  4   month    994 non-null    object
#  5   topic    994 non-null    object
#  6   article  994 non-null    object
# dtypes: int64(1), object(6)
# memory usage: 62.1+ KB

# %% [markdown]
# ## 3. Information Retrieval-based Question Answering (IR-QA) components

# %% [markdown]
# ### 3.1.1 **Article retrieval** to find the top 10 relevant article
#
# `The code is provided as a demonstration; it will different when implemented in the actual application.`

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.neighbors import NearestNeighbors

tfidf_configs = {
    'lowercase': True,
    'analyzer': 'word',
    'stop_words': 'english',
    'binary': True,
    'max_df': 0.9,
    'max_features': 10_000
}

retriever_configs = {
    'n_neighbors': 10,  # Retrieve top 10 nearest neighbors
    'metric': 'cosine'
}

embedding = TfidfVectorizer(**tfidf_configs)
retriever = NearestNeighbors(**retriever_configs)



def article_retrieval(df, question):
    # Fit the TF-IDF vectorizer and the NearestNeighbors model
    X = embedding.fit_transform(df['article'])
    retriever.fit(X, df['id'].values.reshape(-1, 1))

    # Transform the question to find its nearest neighbors
    X_question = embedding.transform([question])

    # Find the indices and distances of the 10 nearest neighbors
    distances, indices = retriever.kneighbors(X_question, return_distance=True)

    # Retrieve the articles, IDs, and distances for the top 10 nearest neighbors
    top_articles = df.iloc[indices[0]]
    for i, (index, row) in enumerate(top_articles.iterrows()):
        distance = distances[0][i]
        print(f"ID: {row['id']}| Article: {row['article'][:50]}...| Similarity: {1-distance:.4f}")
    return top_articles

# %% [markdown]
# ### 3.1.2 Example of `article_retrieval` function

# %%
question = "Who is the vice chairman of Samsung"

top_articles = article_retrieval(df_clean,question)
# Out:
# ID: 17574| Article: SEOUL, South Korea  ?   A special prosecutor inves...| Similarity: 0.1257
# ID: 17764| Article: SEOUL, South Korea  ?   A South Korean court on Th...| Similarity: 0.1235
# ID: 18375| Article: The main reason for the gender gaps at work  ?   w...| Similarity: 0.0920
# ID: 17734| Article: Good morning.  Here?s what you need to know: ? Pre...| Similarity: 0.0819
# ID: 18222| Article: MODERN homes today are getting   light bulbs, ther...| Similarity: 0.0757
# ID: 17929| Article: LONDON  ?   Bernie Ecclestone?s longstanding leade...| Similarity: 0.0700
# ID: 17487| Article: SEATTLE  ?   For a technology to crack the mainstr...| Similarity: 0.0629
# ID: 17851| Article: SAN FRANCISCO  ?   By mastering some tough compute...| Similarity: 0.0610
# ID: 18410| Article: For anyone wondering how former President Barack O...| Similarity: 0.0592
# ID: 17657| Article: ESCONDIDO, Calif.  ?   In Southern California in t...| Similarity: 0.0546

# %% [markdown]
# ### 3.2.1 **Coreference Resolution** for top 10 relevant article
#
# `The code is provided as a demonstration; it will different when implemented in the actual application.`
#
# (Otmazgin, Cattan & Goldberg, 2022).

# %%
from fastcoref import spacy_component
from fastcoref import LingMessCoref
import spacy

model = LingMessCoref()
def Coreference_Resolution(text):
    nlp = spacy.load("en_core_web_sm")
    nlp.add_pipe("fastcoref")
    doc = nlp(text)
    # nlp.add_pipe("fastcoref", config={'model_architecture': 'LingMessCoref', 'model_path': 'biu-nlp/lingmess-coref', 'device': 'cpu'})
    doc = nlp(text, component_cfg={"fastcoref": {'resolve_text': True}})
    return doc._.resolved_text
# Out:
# 03/29/2024 11:21:10 - INFO - 	 missing_keys: []
# 03/29/2024 11:21:10 - INFO - 	 unexpected_keys: []
# 03/29/2024 11:21:10 - INFO - 	 mismatched_keys: []
# 03/29/2024 11:21:10 - INFO - 	 error_msgs: []
# 03/29/2024 11:21:10 - INFO - 	 Model Parameters: 590.0M, Transformer: 434.6M, Coref head: 155.4M

# %% [markdown]
# ### 3.2.2 Example of `Coreference_Resolution` function

# %%
from spacy import displacy

sample = "The de facto leader, Jay Y. Lee, the vice chairman of Samsung, will be questioned on Thursday, according to the special prosecutor?s office, which recommended that he also be investigated on suspicion of perjury."
resolved_text = Coreference_Resolution(sample)

nlp = spacy.load("en_core_web_sm")

doc = nlp(sample)
sample_spans = list(doc.sents)
print("\nOriginal text:")
displacy.render(sample_spans, style="ent")

doc = nlp(resolved_text)
resolved_spans = list(doc.sents)
print("Resolved text:")
displacy.render(resolved_spans, style="ent")
# Out:
# 03/29/2024 11:21:16 - INFO - 	 missing_keys: []
# 03/29/2024 11:21:16 - INFO - 	 unexpected_keys: []
# 03/29/2024 11:21:16 - INFO - 	 mismatched_keys: []
# 03/29/2024 11:21:16 - INFO - 	 error_msgs: []
# 03/29/2024 11:21:16 - INFO - 	 Model Parameters: 90.5M, Transformer: 82.1M, Coref head: 8.4M
# 03/29/2024 11:21:16 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 95.83 examples/s]
# 03/29/2024 11:21:16 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00, 13.22it/s]
# 03/29/2024 11:21:16 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 249.94 examples/s]
# 03/29/2024 11:21:17 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00, 33.33it/s]
# Original text:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">The de facto leader,
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Jay Y. Lee
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# , the vice chairman of
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Samsung
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# , will be questioned on
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Thursday
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# , according to the special
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     prosecutor?s
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  office, which recommended that he also be investigated on suspicion of perjury.</div></span>
# Resolved text:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">The de facto leader,
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Jay Y. Lee
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# , the vice chairman of
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Samsung
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# , will be questioned on
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Thursday
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# , according to the special
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     prosecutor?s
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  office, which recommended that The de facto leader,
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Jay Y. Lee
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
# , the vice chairman of
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Samsung
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# , also be investigated on suspicion of perjury.</div></span>

# %% [markdown]
# ### 3.3.1 **Text matching** to find the most relevant sentence
#
# `The code is provided as a demonstration; it will different when implemented in the actual application.`

# %%
from sklearn.metrics.pairwise import cosine_similarity
import numpy as np
import nltk

def text_matching(top_articles,question):
    sentences = nltk.sent_tokenize(" ".join(top_articles))
    vectorizer = TfidfVectorizer(stop_words='english')
    combined_text = [question] + sentences
    tfidf_matrix = vectorizer.fit_transform(combined_text)
    cosine_similarities = cosine_similarity(tfidf_matrix[0:1], tfidf_matrix[1:])

    # Find the index of the highest similarity score
    most_similar_sentence_index = cosine_similarities.argmax()

    # Return the most relevant sentence and its similarity score
    return sentences[most_similar_sentence_index], cosine_similarities[0, most_similar_sentence_index]

# %% [markdown]
# ### 3.3.2 Example of `text_matching` function

# %%
resolved_article = [Coreference_Resolution(i) for i in top_articles['article']]
# Out:
# 03/29/2024 11:21:32 - INFO - 	 missing_keys: []
# 03/29/2024 11:21:32 - INFO - 	 unexpected_keys: []
# 03/29/2024 11:21:32 - INFO - 	 mismatched_keys: []
# 03/29/2024 11:21:32 - INFO - 	 error_msgs: []
# 03/29/2024 11:21:32 - INFO - 	 Model Parameters: 90.5M, Transformer: 82.1M, Coref head: 8.4M
# 03/29/2024 11:21:32 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 49.98 examples/s]
# 03/29/2024 11:21:32 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00,  6.04it/s]
# 03/29/2024 11:21:32 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 52.65 examples/s]
# 03/29/2024 11:21:32 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00,  6.41it/s]
# 03/29/2024 11:21:33 - INFO - 	 missing_keys: []
# 03/29/2024 11:21:33 - INFO - 	 unexpected_keys: []
# 03/29/2024 11:21:33 - INFO - 	 mismatched_keys: []
# 03/29/2024 11:21:33 - INFO - 	 error_msgs: []
# 03/29/2024 11:21:33 - INFO - 	 Model Parameters: 90.5M, Transformer: 82.1M, Coref head: 8.4M
# 03/29/2024 11:21:33 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 50.01 examples/s]
# 03/29/2024 11:21:34 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00,  5.68it/s]
# 03/29/2024 11:21:34 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 52.57 examples/s]
# 03/29/2024 11:21:34 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00,  5.88it/s]
# 03/29/2024 11:21:35 - INFO - 	 missing_keys: []
# 03/29/2024 11:21:35 - INFO - 	 unexpected_keys: []
# 03/29/2024 11:21:35 - INFO - 	 mismatched_keys: []
# 03/29/2024 11:21:35 - INFO - 	 error_msgs: []
# 03/29/2024 11:21:35 - INFO - 	 Model Parameters: 90.5M, Transformer: 82.1M, Coref head: 8.4M
# 03/29/2024 11:21:35 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 34.47 examples/s]
# 03/29/2024 11:21:35 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00,  4.56it/s]
# 03/29/2024 11:21:36 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 35.71 examples/s]
# 03/29/2024 11:21:36 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00,  4.56it/s]
# 03/29/2024 11:21:37 - INFO - 	 missing_keys: []
# 03/29/2024 11:21:37 - INFO - 	 unexpected_keys: []
# 03/29/2024 11:21:37 - INFO - 	 mismatched_keys: []
# 03/29/2024 11:21:37 - INFO - 	 error_msgs: []
# 03/29/2024 11:21:37 - INFO - 	 Model Parameters: 90.5M, Transformer: 82.1M, Coref head: 8.4M
# 03/29/2024 11:21:37 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 30.30 examples/s]
# 03/29/2024 11:21:38 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00,  4.02it/s]
# 03/29/2024 11:21:38 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 31.25 examples/s]
# 03/29/2024 11:21:38 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00,  4.13it/s]
# 03/29/2024 11:21:39 - INFO - 	 missing_keys: []
# 03/29/2024 11:21:39 - INFO - 	 unexpected_keys: []
# 03/29/2024 11:21:39 - INFO - 	 mismatched_keys: []
# 03/29/2024 11:21:39 - INFO - 	 error_msgs: []
# 03/29/2024 11:21:39 - INFO - 	 Model Parameters: 90.5M, Transformer: 82.1M, Coref head: 8.4M
# 03/29/2024 11:21:40 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 30.30 examples/s]
# 03/29/2024 11:21:40 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00,  3.83it/s]
# 03/29/2024 11:21:40 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 32.25 examples/s]
# 03/29/2024 11:21:40 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00,  3.89it/s]
# 03/29/2024 11:21:42 - INFO - 	 missing_keys: []
# 03/29/2024 11:21:42 - INFO - 	 unexpected_keys: []
# 03/29/2024 11:21:42 - INFO - 	 mismatched_keys: []
# 03/29/2024 11:21:42 - INFO - 	 error_msgs: []
# 03/29/2024 11:21:42 - INFO - 	 Model Parameters: 90.5M, Transformer: 82.1M, Coref head: 8.4M
# 03/29/2024 11:21:42 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 90.93 examples/s]
# 03/29/2024 11:21:42 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00, 13.57it/s]
# 03/29/2024 11:21:42 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 90.91 examples/s]
# 03/29/2024 11:21:42 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00, 13.20it/s]
# 03/29/2024 11:21:43 - INFO - 	 missing_keys: []
# 03/29/2024 11:21:43 - INFO - 	 unexpected_keys: []
# 03/29/2024 11:21:43 - INFO - 	 mismatched_keys: []
# 03/29/2024 11:21:43 - INFO - 	 error_msgs: []
# 03/29/2024 11:21:43 - INFO - 	 Model Parameters: 90.5M, Transformer: 82.1M, Coref head: 8.4M
# 03/29/2024 11:21:43 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 26.32 examples/s]
# 03/29/2024 11:21:43 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00,  4.12it/s]
# 03/29/2024 11:21:44 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 32.77 examples/s]
# 03/29/2024 11:21:44 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00,  4.21it/s]
# 03/29/2024 11:21:45 - INFO - 	 missing_keys: []
# 03/29/2024 11:21:45 - INFO - 	 unexpected_keys: []
# 03/29/2024 11:21:45 - INFO - 	 mismatched_keys: []
# 03/29/2024 11:21:45 - INFO - 	 error_msgs: []
# 03/29/2024 11:21:45 - INFO - 	 Model Parameters: 90.5M, Transformer: 82.1M, Coref head: 8.4M
# 03/29/2024 11:21:45 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 29.41 examples/s]
# 03/29/2024 11:21:46 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00,  3.91it/s]
# 03/29/2024 11:21:46 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 30.30 examples/s]
# 03/29/2024 11:21:46 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00,  3.91it/s]
# 03/29/2024 11:21:48 - INFO - 	 missing_keys: []
# 03/29/2024 11:21:48 - INFO - 	 unexpected_keys: []
# 03/29/2024 11:21:48 - INFO - 	 mismatched_keys: []
# 03/29/2024 11:21:48 - INFO - 	 error_msgs: []
# 03/29/2024 11:21:48 - INFO - 	 Model Parameters: 90.5M, Transformer: 82.1M, Coref head: 8.4M
# 03/29/2024 11:21:48 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 83.34 examples/s]
# 03/29/2024 11:21:48 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00,  9.25it/s]
# 03/29/2024 11:21:48 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 83.27 examples/s]
# 03/29/2024 11:21:48 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00,  9.44it/s]
# 03/29/2024 11:21:49 - INFO - 	 missing_keys: []
# 03/29/2024 11:21:49 - INFO - 	 unexpected_keys: []
# 03/29/2024 11:21:49 - INFO - 	 mismatched_keys: []
# 03/29/2024 11:21:49 - INFO - 	 error_msgs: []
# 03/29/2024 11:21:49 - INFO - 	 Model Parameters: 90.5M, Transformer: 82.1M, Coref head: 8.4M
# 03/29/2024 11:21:50 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 12.50 examples/s]
# 03/29/2024 11:21:50 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00,  1.89it/s]
# 03/29/2024 11:21:50 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 14.08 examples/s]
# 03/29/2024 11:21:51 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00,  1.87it/s]

# %%
sentence, similarity = text_matching(resolved_article,question)

print(f"The most related sentence: {sentence}\nWith {similarity:.4f} similarity")
# Out:
# The most related sentence: Jay Y. Lee, the Samsung vice chairman, has denied accusations that Jay Y. Lee, the Samsung vice chairman, paid more than $36 million in bribes to organizations linked to Choi   the unofficial adviser at the center of the corruption scandal that engulfed President Park  .
# With 0.4675 similarity

# %% [markdown]
# ### 3.4.1 **Type-based Answer Extraction** by name entity
#
# `The code is provided as a demonstration; it will different when implemented in the actual application.`

# %%
def Answer_Extraction(sentence,similarity,question):
    nlp = spacy.load("en_core_web_sm")
    doc = nlp(sentence)
    sample_doc = {i.text:i.label_ for i in doc.ents}
    question = question.lower()
    if similarity > 0.35:
            try:
                if question.startswith('who'):
                    who_list = [k for k,v in sample_doc.items() if v=='PERSON']
                    return who_list[0] if len (who_list)>0 else 'NO ANSWER'
                elif question.startswith('where'):
                    where_list = [k for k,v in sample_doc.items() if v=='LOC' or  v=='GPE']
                    return where_list[0] if len (where_list) >0 else 'NO ANSWER'
                elif question.startswith('when'):
                    when_list = [k for k,v in sample_doc.items() if v=='DATE']
                    return when_list[0] if len (when_list) >0 else 'NO ANSWER'
                elif question.startswith('what'):
                    what_list = [k for k,v in sample_doc.items() if v=='ORG']
                    return what_list[0] if len (what_list) >0 else 'NO ANSWER'
                elif question.startswith('how many'):
                    how_many_list = [k for k,v in sample_doc.items() if v=='MONEY' or  v=='DATE']
                    return how_many_list[0] if len (how_many_list) >0 else 'NO ANSWER'
            except:
                return 'NO ANSWER'
    else:
        return "NO ANSWER"

# %% [markdown]
# ### 3.4.2 Example of `Answer_Extraction` function

# %%
Answer_Extraction(sentence,similarity,question)
# Out:
# 'Jay Y. Lee'

# %% [markdown]
# ### 3.5.1 Bert for Question Answering
#
# `The code is provided as a demonstration; it will different when implemented in the actual application.`

# %%
import torch
from transformers import BertForQuestionAnswering, BertTokenizer

def bert(sentence,similarity,question):
    if similarity > 0.35:
        model = BertForQuestionAnswering.from_pretrained('bert-large-uncased-whole-word-masking-finetuned-squad')
        tokenizer = BertTokenizer.from_pretrained('bert-large-uncased-whole-word-masking-finetuned-squad')
        
        input_ids = tokenizer.encode(question, sentence, max_length=512, truncation=True)

        tokens = tokenizer.convert_ids_to_tokens(input_ids)
        sep_index = input_ids.index(tokenizer.sep_token_id)
        num_seg_a = sep_index + 1
        num_seg_b = len(input_ids) - num_seg_a
        segment_ids = [0]*num_seg_a + [1]*num_seg_b

        model_scores = model.forward(torch.tensor([input_ids]),token_type_ids=torch.tensor([segment_ids]))

        start_scores = model_scores.start_logits
        end_scores = model_scores.end_logits

        answer_start = torch.argmax(start_scores)
        answer_end = torch.argmax(end_scores)

        return ' '.join(tokens[answer_start:answer_end+1])
    
    else:
        return "NO ANSWER"

# %% [markdown]
# ### 3.5.2 Example of `bert` function

# %%
bert(sentence,similarity,question)
# Out:
# 'jay y . lee'

# %% [markdown]
# ## 4. The IR-QA system and model selection

# %% [markdown]
# ### 4.1 The IR-QA system for medel selection

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.neighbors import NearestNeighbors
from fastcoref import spacy_component
from fastcoref import LingMessCoref
import spacy
from sklearn.metrics.pairwise import cosine_similarity
import numpy as np
import nltk
import torch
from transformers import BertForQuestionAnswering, BertTokenizer


class Information_Retrieval_System_model_selection:
    def __init__(self,model, df, question):
        self.df = df
        self.question = question
        self.model = model

        self.top_articles = self.article_retrieval(df, question)
        self.resolved_articles = [self.Coreference_Resolution(article) for article in self.top_articles['article']]
        self.most_relevant_sentence, self.similarity = self.text_matching(self.resolved_articles, question)

    
    def article_retrieval(self,df, question):
        tfidf_configs = {
            'lowercase': True,
            'analyzer': 'word',
            'stop_words': 'english',
            'binary': True,
            'max_df': 0.9,
            'max_features': 10_000
        }

        retriever_configs = {
            'n_neighbors': 10, 
            'metric': 'cosine'
        }

        embedding = TfidfVectorizer(**tfidf_configs)
        retriever = NearestNeighbors(**retriever_configs)

        X = embedding.fit_transform(df['article'])
        retriever.fit(X, df['id'].values.reshape(-1, 1))

        X_question = embedding.transform([question])

        distances, indices = retriever.kneighbors(X_question, return_distance=True)

        return df.iloc[indices[0]]
    
    def Coreference_Resolution(self,text):
        nlp = spacy.load(self.model)
        nlp.add_pipe("fastcoref")
        doc = nlp(text)
        # nlp.add_pipe("fastcoref", config={'model_architecture': 'LingMessCoref', 'model_path': 'biu-nlp/lingmess-coref', 'device': 'cpu'})
        doc = nlp(text, component_cfg={"fastcoref": {'resolve_text': True}})
        return doc._.resolved_text
    
    def text_matching(self,top_articles,question):
        sentences = nltk.sent_tokenize(" ".join(top_articles))
        vectorizer = TfidfVectorizer(stop_words='english')
        combined_text = [question] + sentences
        tfidf_matrix = vectorizer.fit_transform(combined_text)
        cosine_similarities = cosine_similarity(tfidf_matrix[0:1], tfidf_matrix[1:])

        # Find the index of the highest similarity score
        most_similar_sentence_index = cosine_similarities.argmax()

        # Return the most relevant sentence and its similarity score
        return sentences[most_similar_sentence_index], cosine_similarities[0, most_similar_sentence_index]
    
    def Answer_Extraction(self,sentence,similarity,question):
        nlp = spacy.load(self.model)
        doc = nlp(sentence)
        sample_doc = {i.text:i.label_ for i in doc.ents}
        question = question.lower()
        if similarity > 0.35:
                try:
                    if question.startswith('who'):
                        who_list = [k for k,v in sample_doc.items() if v=='PERSON']
                        return who_list[0] if len (who_list)>0 else 'NO ANSWER'
                    elif question.startswith('where'):
                        where_list = [k for k,v in sample_doc.items() if v=='LOC' or  v=='GPE']
                        return where_list[0] if len (where_list) >0 else 'NO ANSWER'
                    elif question.startswith('when'):
                        when_list = [k for k,v in sample_doc.items() if v=='DATE']
                        return when_list[0] if len (when_list) >0 else 'NO ANSWER'
                    elif question.startswith('what'):
                        what_list = [k for k,v in sample_doc.items() if v=='ORG']
                        return what_list[0] if len (what_list) >0 else 'NO ANSWER'
                    elif question.startswith('how many'):
                        how_many_list = [k for k,v in sample_doc.items() if v=='MONEY' or  v=='DATE']
                        return how_many_list[0] if len (how_many_list) >0 else 'NO ANSWER'
                except:
                    return 'NO ANSWER'
        else:
            return "NO ANSWER"

    def Rule_base(self):
        return self.Answer_Extraction(self.most_relevant_sentence, self.similarity, self.question)

    
    def Bert(self):
        model = BertForQuestionAnswering.from_pretrained('bert-large-uncased-whole-word-masking-finetuned-squad')
        tokenizer = BertTokenizer.from_pretrained('bert-large-uncased-whole-word-masking-finetuned-squad')

        if self.similarity > 0.35:
            input_ids = tokenizer.encode(self.question, self.most_relevant_sentence, max_length=512, truncation=True)

            tokens = tokenizer.convert_ids_to_tokens(input_ids)
            sep_index = input_ids.index(tokenizer.sep_token_id)
            num_seg_a = sep_index + 1
            num_seg_b = len(input_ids) - num_seg_a
            segment_ids = [0]*num_seg_a + [1]*num_seg_b

            model_scores = model.forward(torch.tensor([input_ids]),token_type_ids=torch.tensor([segment_ids]))

            start_scores = model_scores.start_logits
            end_scores = model_scores.end_logits

            answer_start = torch.argmax(start_scores)
            answer_end = torch.argmax(end_scores)

            return ' '.join(tokens[answer_start:answer_end+1])
        else:
            return "NO ANSWER"

# %% [markdown]
# ### 4.2 The 20 self-defined questions

# %%
self_define_question_df = pd.read_csv("Test_question.csv", encoding="ISO-8859-1")

self_define_question_df.head()
# Out:
#       id                                           question  \
# 0  17574               Who is the vice chairman of Samsung?
# 1  17344               What was Chen Zhongshu the head of?'
# 2  17579      What unexpected product contains added sugar?
# 3  17598  What does the Trump administration frequently ...
# 4  17620      What date did Steve Harvey meet Donald Trump?
#
#                                 answer
# 0                           Jay Y. Lee
# 1  Panzhihua Land and Resources Bureau
# 2                            NO ANSWER
# 3                            NO ANSWER
# 4                            NO ANSWER

# %% [markdown]
# ### 4.3 Evaluation metric
#
# F1 score, Exact Match and output timing was used to evaluate the model. Since the usual F1 from sklearn is designed for calculate numeric data, therefore it is not applicable in the NLP task. Referring to the Evaluation Scripts v2.0 from SQuAD GitHub, it provides the calculation of F1 score and Exact Match. In this assignment will use it as an evaluation metrics (The Stanford NLP Group 2024).

# %%
import collections
import re
import string

def normalize_answer(s):
  """Lower text and remove punctuation, articles and extra whitespace."""
  def remove_articles(text):
    regex = re.compile(r'\b(a|an|the)\b', re.UNICODE)
    return re.sub(regex, ' ', text)
  def white_space_fix(text):
    return ' '.join(text.split())
  def remove_punc(text):
    exclude = set(string.punctuation)
    return ''.join(ch for ch in text if ch not in exclude)
  def lower(text):
    return text.lower()
  return white_space_fix(remove_articles(remove_punc(lower(s))))

def get_tokens(s):
  if not s: return []
  return normalize_answer(s).split()

def compute_exact(a_gold, a_pred):
  return int(normalize_answer(a_gold) == normalize_answer(a_pred))

def compute_f1(a_gold, a_pred):
  gold_toks = get_tokens(a_gold)
  pred_toks = get_tokens(a_pred)
  common = collections.Counter(gold_toks) & collections.Counter(pred_toks)
  num_same = sum(common.values())
  if len(gold_toks) == 0 or len(pred_toks) == 0:
    # If either is no-answer, then F1 is 1 if they agree, 0 otherwise
    return int(gold_toks == pred_toks)
  if num_same == 0:
    return 0
  precision = 1.0 * num_same / len(pred_toks)
  recall = 1.0 * num_same / len(gold_toks)
  f1 = (2 * precision * recall) / (precision + recall)
  return f1

# %% [markdown]
# ### 4.4 Model selection with validation

# %%
import time
import pandas as pd
from sklearn.model_selection import KFold

# Initialize KFold
kf = KFold(n_splits=5)

# Evaluation function
def evaluate_model(model_name, data):
    fold_f1_scores_rule = []
    fold_exact_matches_rule = []
    fold_times_rule = []

    fold_f1_scores_bert = []
    fold_exact_matches_bert = []
    fold_times_bert = []

    for _, test_index in kf.split(data):
        test_data = data.iloc[test_index]
        
        f1_scores_rule = []
        exact_matches_rule = []
        times_rule = []

        f1_scores_bert = []
        exact_matches_bert = []
        times_bert = []

        for _, row in test_data.iterrows():
            question = row['question']
            gold_answer = row['answer']

            # Initialize the system for each question
            system = Information_Retrieval_System_model_selection(model_name, df_clean, question)

            # Rule-based prediction
            start_time_rule = time.time()
            predicted_answer_rule = system.Rule_base()
            times_rule.append(time.time() - start_time_rule)
            
            f1_scores_rule.append(compute_f1(gold_answer, predicted_answer_rule))
            exact_matches_rule.append(compute_exact(gold_answer, predicted_answer_rule))

            # BERT-based prediction
            start_time_bert = time.time()
            predicted_answer_bert = system.Bert()
            times_bert.append(time.time() - start_time_bert)

            f1_scores_bert.append(compute_f1(gold_answer, predicted_answer_bert))
            exact_matches_bert.append(compute_exact(gold_answer, predicted_answer_bert))

        # Calculate and store the averages for this fold
        fold_f1_scores_rule.append(sum(f1_scores_rule) / len(f1_scores_rule))
        fold_exact_matches_rule.append(sum(exact_matches_rule) / len(exact_matches_rule))
        fold_times_rule.append(sum(times_rule) / len(times_rule))

        fold_f1_scores_bert.append(sum(f1_scores_bert) / len(f1_scores_bert))
        fold_exact_matches_bert.append(sum(exact_matches_bert) / len(exact_matches_bert))
        fold_times_bert.append(sum(times_bert) / len(times_bert))

    # Calculate overall average scores across all folds
    overall_avg_f1_rule = sum(fold_f1_scores_rule) / len(fold_f1_scores_rule)
    overall_avg_exact_match_rule = sum(fold_exact_matches_rule) / len(fold_exact_matches_rule)
    overall_avg_time_rule = sum(fold_times_rule) / len(fold_times_rule)

    overall_avg_f1_bert = sum(fold_f1_scores_bert) / len(fold_f1_scores_bert)
    overall_avg_exact_match_bert = sum(fold_exact_matches_bert) / len(fold_exact_matches_bert)
    overall_avg_time_bert = sum(fold_times_bert) / len(fold_times_bert)

    return (overall_avg_f1_rule, overall_avg_exact_match_rule, overall_avg_time_rule,
            overall_avg_f1_bert, overall_avg_exact_match_bert, overall_avg_time_bert)

# %%
# Main evaluation loop
model_list = ["en_core_web_sm", "en_core_web_trf", "en_core_web_md", "en_core_web_lg"]
model_results = {}

for model_name in model_list:
    results = evaluate_model(model_name, self_define_question_df)
    model_results[model_name] = {
        'Rule-based': {'F1': results[0],'Exact Match': results[1],'Time': results[2]},
        'BERT': {'F1': results[3],'Exact Match': results[4],'Time': results[5]}
    }

# Display the results
for model, scores in model_results.items():
    print(f"Model: {model}")
    for method, metrics in scores.items():
        print(f"  {method}: F1: {metrics['F1']}, Exact Match: {metrics['Exact Match']}, Time: {metrics['Time']} sec")
# Out:
# 03/30/2024 12:04:05 - INFO - 	 missing_keys: []
# 03/30/2024 12:04:05 - INFO - 	 unexpected_keys: []
# 03/30/2024 12:04:05 - INFO - 	 mismatched_keys: []
# 03/30/2024 12:04:05 - INFO - 	 error_msgs: []
# 03/30/2024 12:04:05 - INFO - 	 Model Parameters: 90.5M, Transformer: 82.1M, Coref head: 8.4M
# 03/30/2024 12:04:05 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 45.49 examples/s]
# 03/30/2024 12:04:05 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00,  6.50it/s]
# 03/30/2024 12:04:05 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 45.44 examples/s]
# 03/30/2024 12:04:05 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00,  6.71it/s]
# 03/30/2024 12:04:07 - INFO - 	 missing_keys: []
# 03/30/2024 12:04:07 - INFO - 	 unexpected_keys: []
# 03/30/2024 12:04:07 - INFO - 	 mismatched_keys: []
# 03/30/2024 12:04:07 - INFO - 	 error_msgs: []
# 03/30/2024 12:04:07 - INFO - 	 Model Parameters: 90.5M, Transformer: 82.1M, Coref head: 8.4M
# 03/30/2024 12:04:07 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 45.44 examples/s]
# 03/30/2024 12:04:07 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00,  5.97it/s]
# 03/30/2024 12:04:07 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 47.62 examples/s]
# 03/30/2024 12:04:07 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00,  6.13it/s]
# 03/30/2024 12:04:09 - INFO - 	 missing_keys: []
# 03/30/2024 12:04:09 - INFO - 	 unexpected_keys: []
# 03/30/2024 12:04:09 - INFO - 	 mismatched_keys: []
# 03/30/2024 12:04:09 - INFO - 	 error_msgs: []
# 03/30/2024 12:04:09 - INFO - 	 Model Parameters: 90.5M, Transformer: 82.1M, Coref head: 8.4M
# 03/30/2024 12:04:09 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 30.30 examples/s]
# 03/30/2024 12:04:09 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00,  4.76it/s]
# 03/30/2024 12:04:09 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 32.26 examples/s]
# 03/30/2024 12:04:10 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00,  4.72it/s]
# 03/30/2024 12:04:11 - INFO - 	 missing_keys: []
# 03/30/2024 12:04:11 - INFO - 	 unexpected_keys: []
# 03/30/2024 12:04:11 - INFO - 	 mismatched_keys: []
# 03/30/2024 12:04:11 - INFO - 	 error_msgs: []
# 03/30/2024 12:04:11 - INFO - 	 Model Parameters: 90.5M, Transformer: 82.1M, Coref head: 8.4M
# 03/30/2024 12:04:11 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 25.69 examples/s]
# 03/30/2024 12:04:11 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00,  4.31it/s]
# 03/30/2024 12:04:12 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 27.77 examples/s]
# 03/30/2024 12:04:12 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00,  4.20it/s]
# 03/30/2024 12:04:13 - INFO - 	 missing_keys: []
# 03/30/2024 12:04:13 - INFO - 	 unexpected_keys: []
# 03/30/2024 12:04:13 - INFO - 	 mismatched_keys: []
# 03/30/2024 12:04:13 - INFO - 	 error_msgs: []
# 03/30/2024 12:04:13 - INFO - 	 Model Parameters: 90.5M, Transformer: 82.1M, Coref head: 8.4M
# 03/30/2024 12:04:13 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 29.41 examples/s]
# 03/30/2024 12:04:13 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00,  3.94it/s]
# 03/30/2024 12:04:14 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 30.30 examples/s]
# 03/30/2024 12:04:14 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00,  3.94it/s]
# 03/30/2024 12:04:15 - INFO - 	 missing_keys: []
# 03/30/2024 12:04:15 - INFO - 	 unexpected_keys: []
# 03/30/2024 12:04:15 - INFO - 	 mismatched_keys: []
# 03/30/2024 12:04:15 - INFO - 	 error_msgs: []
# 03/30/2024 12:04:15 - INFO - 	 Model Parameters: 90.5M, Transformer: 82.1M, Coref head: 8.4M
# 03/30/2024 12:04:15 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 90.89 examples/s]
# 03/30/2024 12:04:15 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00, 13.90it/s]
# 03/30/2024 12:04:16 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 99.99 examples/s]
# 03/30/2024 12:04:16 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00, 14.52it/s]
# 03/30/2024 12:04:17 - INFO - 	 missing_keys: []
# 03/30/2024 12:04:17 - INFO - 	 unexpected_keys: []
# 03/30/2024 12:04:17 - INFO - 	 mismatched_keys: []
# 03/30/2024 12:04:17 - INFO - 	 error_msgs: []
# 03/30/2024 12:04:17 - INFO - 	 Model Parameters: 90.5M, Transformer: 82.1M, Coref head: 8.4M
# 03/30/2024 12:04:17 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 27.77 examples/s]
# 03/30/2024 12:04:17 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00,  4.28it/s]
# 03/30/2024 12:04:17 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 28.57 examples/s]
# 03/30/2024 12:04:18 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00,  4.24it/s]
# 03/30/2024 12:04:19 - INFO - 	 missing_keys: []
# 03/30/2024 12:04:19 - INFO - 	 unexpected_keys: []
# 03/30/2024 12:04:19 - INFO - 	 mismatched_keys: []
# 03/30/2024 12:04:19 - INFO - 	 error_msgs: []
# 03/30/2024 12:04:19 - INFO - 	 Model Parameters: 90.5M, Transformer: 82.1M, Coref head: 8.4M
# 03/30/2024 12:04:19 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 25.64 examples/s]
# 03/30/2024 12:04:19 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00,  4.24it/s]
# 03/30/2024 12:04:20 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 27.03 examples/s]
# 03/30/2024 12:04:20 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00,  4.08it/s]
# 03/30/2024 12:04:21 - INFO - 	 missing_keys: []
# 03/30/2024 12:04:21 - INFO - 	 unexpected_keys: []
# 03/30/2024 12:04:21 - INFO - 	 mismatched_keys: []
# 03/30/2024 12:04:21 - INFO - 	 error_msgs: []
# 03/30/2024 12:04:21 - INFO - 	 Model Parameters: 90.5M, Transformer: 82.1M, Coref head: 8.4M
# 03/30/2024 12:04:21 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 71.41 examples/s]
# 03/30/2024 12:04:21 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00,  9.14it/s]
# 03/30/2024 12:04:22 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 71.43 examples/s]
# 03/30/2024 12:04:22 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00,  9.45it/s]
# 03/30/2024 12:04:23 - INFO - 	 missing_keys: []
# 03/30/2024 12:04:23 - INFO - 	 unexpected_keys: []
# 03/30/2024 12:04:23 - INFO - 	 mismatched_keys: []
# 03/30/2024 12:04:23 - INFO - 	 error_msgs: []
# 03/30/2024 12:04:23 - INFO - 	 Model Parameters: 90.5M, Transformer: 82.1M, Coref head: 8.4M
# 03/30/2024 12:04:23 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 12.50 examples/s]
# 03/30/2024 12:04:23 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00,  1.95it/s]
# 03/30/2024 12:04:24 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 13.48 examples/s]
# 03/30/2024 12:04:24 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00,  1.94it/s]
# 03/30/2024 12:04:29 - INFO - 	 missing_keys: []
# 03/30/2024 12:04:29 - INFO - 	 unexpected_keys: []
# 03/30/2024 12:04:29 - INFO - 	 mismatched_keys: []
# 03/30/2024 12:04:29 - INFO - 	 error_msgs: []
# 03/30/2024 12:04:29 - INFO - 	 Model Parameters: 90.5M, Transformer: 82.1M, Coref head: 8.4M
# 03/30/2024 12:04:29 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 83.28 examples/s]
# 03/30/2024 12:04:29 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00, 11.37it/s]
# 03/30/2024 12:04:29 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 90.91 examples/s]
# 03/30/2024 12:04:29 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00, 11.75it/s]
# 03/30/2024 12:04:31 - INFO - 	 missing_keys: []
# 03/30/2024 12:04:31 - INFO - 	 unexpected_keys: []
# 03/30/2024 12:04:31 - INFO - 	 mismatched_keys: []
# 03/30/2024 12:04:31 - INFO - 	 error_msgs: []
# 03/30/2024 12:04:31 - INFO - 	 Model Parameters: 90.5M, Transformer: 82.1M, Coref head: 8.4M
# 03/30/2024 12:04:31 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 76.88 examples/s]
# 03/30/2024 12:04:31 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00,  9.69it/s]
# 03/30/2024 12:04:31 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 76.88 examples/s]
# 03/30/2024 12:04:31 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00, 11.11it/s]
# 03/30/2024 12:04:32 - INFO - 	 missing_keys: []
# 03/30/2024 12:04:32 - INFO - 	 unexpected_keys: []
# 03/30/2024 12:04:32 - INFO - 	 mismatched_keys: []
# 03/30/2024 12:04:32 - INFO - 	 error_msgs: []
# 03/30/2024 12:04:32 - INFO - 	 Model Parameters: 90.5M, Transformer: 82.1M, Coref head: 8.4M
# 03/30/2024 12:04:33 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 83.69 examples/s]
# 03/30/2024 12:04:33 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00, 10.50it/s]
# 03/30/2024 12:04:33 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 76.93 examples/s]
# 03/30/2024 12:04:33 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00, 10.31it/s]
# 03/30/2024 12:04:34 - INFO - 	 missing_keys: []
# 03/30/2024 12:04:34 - INFO - 	 unexpected_keys: []
# 03/30/2024 12:04:34 - INFO - 	 mismatched_keys: []
# 03/30/2024 12:04:34 - INFO - 	 error_msgs: []
# 03/30/2024 12:04:34 - INFO - 	 Model Parameters: 90.5M, Transformer: 82.1M, Coref head: 8.4M
# 03/30/2024 12:04:34 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 71.42 examples/s]
# 03/30/2024 12:04:34 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00, 11.93it/s]
# 03/30/2024 12:04:34 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 76.92 examples/s]
# 03/30/2024 12:04:34 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00, 11.38it/s]
# 03/30/2024 12:04:36 - INFO - 	 missing_keys: []
# 03/30/2024 12:04:36 - INFO - 	 unexpected_keys: []
# 03/30/2024 12:04:36 - INFO - 	 mismatched_keys: []
# 03/30/2024 12:04:36 - INFO - 	 error_msgs: []
# 03/30/2024 12:04:36 - INFO - 	 Model Parameters: 90.5M, Transformer: 82.1M, Coref head: 8.4M
# 03/30/2024 12:04:36 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 66.67 examples/s]
# 03/30/2024 12:04:36 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00,  7.26it/s]
# 03/30/2024 12:04:36 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 71.43 examples/s]
# 03/30/2024 12:04:36 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00,  7.77it/s]
# 03/30/2024 12:04:37 - INFO - 	 missing_keys: []
# 03/30/2024 12:04:37 - INFO - 	 unexpected_keys: []
# 03/30/2024 12:04:37 - INFO - 	 mismatched_keys: []
# 03/30/2024 12:04:37 - INFO - 	 error_msgs: []
# 03/30/2024 12:04:37 - INFO - 	 Model Parameters: 90.5M, Transformer: 82.1M, Coref head: 8.4M
# 03/30/2024 12:04:37 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 62.50 examples/s]
# 03/30/2024 12:04:38 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00,  7.93it/s]
# 03/30/2024 12:04:38 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 58.83 examples/s]
# 03/30/2024 12:04:38 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00,  7.96it/s]
# 03/30/2024 12:04:39 - INFO - 	 missing_keys: []
# 03/30/2024 12:04:39 - INFO - 	 unexpected_keys: []
# 03/30/2024 12:04:39 - INFO - 	 mismatched_keys: []
# 03/30/2024 12:04:39 - INFO - 	 error_msgs: []
# 03/30/2024 12:04:39 - INFO - 	 Model Parameters: 90.5M, Transformer: 82.1M, Coref head: 8.4M
# 03/30/2024 12:04:39 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 62.45 examples/s]
# 03/30/2024 12:04:39 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00,  8.86it/s]
# 03/30/2024 12:04:40 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 71.39 examples/s]
# 03/30/2024 12:04:40 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00,  9.39it/s]
# 03/30/2024 12:04:41 - INFO - 	 missing_keys: []
# 03/30/2024 12:04:41 - INFO - 	 unexpected_keys: []
# 03/30/2024 12:04:41 - INFO - 	 mismatched_keys: []
# 03/30/2024 12:04:41 - INFO - 	 error_msgs: []
# 03/30/2024 12:04:41 - INFO - 	 Model Parameters: 90.5M, Transformer: 82.1M, Coref head: 8.4M
# 03/30/2024 12:04:41 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 66.63 examples/s]
# 03/30/2024 12:04:41 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00,  8.04it/s]
# 03/30/2024 12:04:41 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 71.43 examples/s]
# 03/30/2024 12:04:41 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00,  8.38it/s]
# 03/30/2024 12:04:43 - INFO - 	 missing_keys: []
# 03/30/2024 12:04:43 - INFO - 	 unexpected_keys: []
# 03/30/2024 12:04:43 - INFO - 	 mismatched_keys: []
# 03/30/2024 12:04:43 - INFO - 	 error_msgs: []
# 03/30/2024 12:04:43 - INFO - 	 Model Parameters: 90.5M, Transformer: 82.1M, Coref head: 8.4M
# 03/30/2024 12:04:43 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 41.67 examples/s]
# 03/30/2024 12:04:43 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00,  5.56it/s]
# 03/30/2024 12:04:43 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 47.62 examples/s]
# 03/30/2024 12:04:43 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00,  5.47it/s]
# 03/30/2024 12:04:45 - INFO - 	 missing_keys: []
# 03/30/2024 12:04:45 - INFO - 	 unexpected_keys: []
# 03/30/2024 12:04:45 - INFO - 	 mismatched_keys: []
# 03/30/2024 12:04:45 - INFO - 	 error_msgs: []
# 03/30/2024 12:04:45 - INFO - 	 Model Parameters: 90.5M, Transformer: 82.1M, Coref head: 8.4M
# 03/30/2024 12:04:45 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 55.53 examples/s]
# 03/30/2024 12:04:45 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00,  6.94it/s]
# 03/30/2024 12:04:45 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 58.83 examples/s]
# 03/30/2024 12:04:45 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00,  7.09it/s]
# 03/30/2024 12:04:49 - INFO - 	 missing_keys: []
# 03/30/2024 12:04:49 - INFO - 	 unexpected_keys: []
# 03/30/2024 12:04:49 - INFO - 	 mismatched_keys: []
# 03/30/2024 12:04:49 - INFO - 	 error_msgs: []
# 03/30/2024 12:04:49 - INFO - 	 Model Parameters: 90.5M, Transformer: 82.1M, Coref head: 8.4M
# 03/30/2024 12:04:49 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 66.15 examples/s]
# 03/30/2024 12:04:49 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00, 11.09it/s]
# 03/30/2024 12:04:49 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 71.43 examples/s]
# 03/30/2024 12:04:49 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00, 11.77it/s]
# 03/30/2024 12:04:51 - INFO - 	 missing_keys: []
# 03/30/2024 12:04:51 - INFO - 	 unexpected_keys: []
# 03/30/2024 12:04:51 - INFO - 	 mismatched_keys: []
# 03/30/2024 12:04:51 - INFO - 	 error_msgs: []
# 03/30/2024 12:04:51 - INFO - 	 Model Parameters: 90.5M, Transformer: 82.1M, Coref head: 8.4M
# 03/30/2024 12:04:51 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 22.73 examples/s]
# 03/30/2024 12:04:51 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00,  3.68it/s]
# 03/30/2024 12:04:51 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 20.83 examples/s]
# 03/30/2024 12:04:51 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00,  3.60it/s]
# 03/30/2024 12:04:53 - INFO - 	 missing_keys: []
# 03/30/2024 12:04:53 - INFO - 	 unexpected_keys: []
# 03/30/2024 12:04:53 - INFO - 	 mismatched_keys: []
# 03/30/2024 12:04:53 - INFO - 	 error_msgs: []
# 03/30/2024 12:04:53 - INFO - 	 Model Parameters: 90.5M, Transformer: 82.1M, Coref head: 8.4M
# 03/30/2024 12:04:53 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 24.39 examples/s]
# 03/30/2024 12:04:53 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00,  3.71it/s]
# 03/30/2024 12:04:54 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 27.03 examples/s]
# 03/30/2024 12:04:54 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00,  3.80it/s]
# 03/30/2024 12:04:55 - INFO - 	 missing_keys: []
# 03/30/2024 12:04:55 - INFO - 	 unexpected_keys: []
# 03/30/2024 12:04:55 - INFO - 	 mismatched_keys: []
# 03/30/2024 12:04:55 - INFO - 	 error_msgs: []
# 03/30/2024 12:04:55 - INFO - 	 Model Parameters: 90.5M, Transformer: 82.1M, Coref head: 8.4M
# 03/30/2024 12:04:55 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 37.18 examples/s]
# 03/30/2024 12:04:55 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00,  6.27it/s]
# 03/30/2024 12:04:56 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 43.48 examples/s]
# 03/30/2024 12:04:56 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00,  6.33it/s]
# 03/30/2024 12:04:57 - INFO - 	 missing_keys: []
# 03/30/2024 12:04:57 - INFO - 	 unexpected_keys: []
# 03/30/2024 12:04:57 - INFO - 	 mismatched_keys: []
# 03/30/2024 12:04:57 - INFO - 	 error_msgs: []
# 03/30/2024 12:04:57 - INFO - 	 Model Parameters: 90.5M, Transformer: 82.1M, Coref head: 8.4M
# 03/30/2024 12:04:57 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 45.23 examples/s]
# 03/30/2024 12:04:58 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00,  6.26it/s]
# 03/30/2024 12:04:58 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 47.62 examples/s]
# 03/30/2024 12:04:58 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00,  6.56it/s]
# 03/30/2024 12:04:59 - INFO - 	 missing_keys: []
# 03/30/2024 12:04:59 - INFO - 	 unexpected_keys: []
# 03/30/2024 12:04:59 - INFO - 	 mismatched_keys: []
# 03/30/2024 12:04:59 - INFO - 	 error_msgs: []
# 03/30/2024 12:04:59 - INFO - 	 Model Parameters: 90.5M, Transformer: 82.1M, Coref head: 8.4M
# 03/30/2024 12:04:59 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 20.00 examples/s]
# 03/30/2024 12:05:00 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00,  2.99it/s]
# 03/30/2024 12:05:00 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 23.26 examples/s]
# 03/30/2024 12:05:00 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00,  2.87it/s]
# 03/30/2024 12:05:02 - INFO - 	 missing_keys: []
# 03/30/2024 12:05:02 - INFO - 	 unexpected_keys: []
# 03/30/2024 12:05:02 - INFO - 	 mismatched_keys: []
# 03/30/2024 12:05:02 - INFO - 	 error_msgs: []
# 03/30/2024 12:05:02 - INFO - 	 Model Parameters: 90.5M, Transformer: 82.1M, Coref head: 8.4M
# 03/30/2024 12:05:02 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 18.50 examples/s]
# 03/30/2024 12:05:02 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00,  2.62it/s]
# 03/30/2024 12:05:03 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 21.74 examples/s]
# 03/30/2024 12:05:03 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00,  1.79it/s]
# 03/30/2024 12:05:04 - INFO - 	 missing_keys: []
# 03/30/2024 12:05:04 - INFO - 	 unexpected_keys: []
# 03/30/2024 12:05:04 - INFO - 	 mismatched_keys: []
# 03/30/2024 12:05:04 - INFO - 	 error_msgs: []
# 03/30/2024 12:05:04 - INFO - 	 Model Parameters: 90.5M, Transformer: 82.1M, Coref head: 8.4M
# 03/30/2024 12:05:04 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 62.42 examples/s]
# 03/30/2024 12:05:05 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00,  8.00it/s]
# 03/30/2024 12:05:05 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 66.66 examples/s]
# 03/30/2024 12:05:05 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00,  7.21it/s]
# 03/30/2024 12:05:06 - INFO - 	 missing_keys: []
# 03/30/2024 12:05:06 - INFO - 	 unexpected_keys: []
# 03/30/2024 12:05:06 - INFO - 	 mismatched_keys: []
# 03/30/2024 12:05:06 - INFO - 	 error_msgs: []
# 03/30/2024 12:05:06 - INFO - 	 Model Parameters: 90.5M, Transformer: 82.1M, Coref head: 8.4M
# 03/30/2024 12:05:06 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 35.70 examples/s]
# 03/30/2024 12:05:06 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00,  5.08it/s]
# 03/30/2024 12:05:07 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 40.00 examples/s]
# 03/30/2024 12:05:07 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00,  5.19it/s]
# 03/30/2024 12:05:08 - INFO - 	 missing_keys: []
# 03/30/2024 12:05:08 - INFO - 	 unexpected_keys: []
# 03/30/2024 12:05:08 - INFO - 	 mismatched_keys: []
# 03/30/2024 12:05:08 - INFO - 	 error_msgs: []
# 03/30/2024 12:05:08 - INFO - 	 Model Parameters: 90.5M, Transformer: 82.1M, Coref head: 8.4M
# 03/30/2024 12:05:08 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 17.86 examples/s]
# 03/30/2024 12:05:08 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00,  2.19it/s]
# 03/30/2024 12:05:09 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 18.18 examples/s]
# 03/30/2024 12:05:09 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00,  2.13it/s]
# 03/30/2024 12:05:13 - INFO - 	 missing_keys: []
# 03/30/2024 12:05:13 - INFO - 	 unexpected_keys: []
# 03/30/2024 12:05:13 - INFO - 	 mismatched_keys: []
# 03/30/2024 12:05:13 - INFO - 	 error_msgs: []
# 03/30/2024 12:05:13 - INFO - 	 Model Parameters: 90.5M, Transformer: 82.1M, Coref head: 8.4M
# 03/30/2024 12:05:13 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 90.83 examples/s]
# 03/30/2024 12:05:14 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00, 11.37it/s]
# 03/30/2024 12:05:14 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 99.92 examples/s]
# 03/30/2024 12:05:14 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00, 11.50it/s]
# 03/30/2024 12:05:16 - INFO - 	 missing_keys: []
# 03/30/2024 12:05:16 - INFO - 	 unexpected_keys: []
# 03/30/2024 12:05:16 - INFO - 	 mismatched_keys: []
# 03/30/2024 12:05:16 - INFO - 	 error_msgs: []
# 03/30/2024 12:05:16 - INFO - 	 Model Parameters: 90.5M, Transformer: 82.1M, Coref head: 8.4M
# 03/30/2024 12:05:16 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 50.00 examples/s]
# 03/30/2024 12:05:16 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00,  6.93it/s]
# 03/30/2024 12:05:16 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 52.63 examples/s]
# 03/30/2024 12:05:16 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00,  6.82it/s]
# 03/30/2024 12:05:17 - INFO - 	 missing_keys: []
# 03/30/2024 12:05:17 - INFO - 	 unexpected_keys: []
# 03/30/2024 12:05:17 - INFO - 	 mismatched_keys: []
# 03/30/2024 12:05:17 - INFO - 	 error_msgs: []
# 03/30/2024 12:05:17 - INFO - 	 Model Parameters: 90.5M, Transformer: 82.1M, Coref head: 8.4M
# 03/30/2024 12:05:18 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 25.64 examples/s]
# 03/30/2024 12:05:18 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00,  3.24it/s]
# 03/30/2024 12:05:18 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 23.81 examples/s]
# 03/30/2024 12:05:18 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00,  3.27it/s]
# 03/30/2024 12:05:20 - INFO - 	 missing_keys: []
# 03/30/2024 12:05:20 - INFO - 	 unexpected_keys: []
# 03/30/2024 12:05:20 - INFO - 	 mismatched_keys: []
# 03/30/2024 12:05:20 - INFO - 	 error_msgs: []
# 03/30/2024 12:05:20 - INFO - 	 Model Parameters: 90.5M, Transformer: 82.1M, Coref head: 8.4M
# 03/30/2024 12:05:20 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 35.70 examples/s]
# 03/30/2024 12:05:20 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00,  4.73it/s]
# 03/30/2024 12:05:20 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 35.71 examples/s]
# 03/30/2024 12:05:20 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00,  4.93it/s]
# 03/30/2024 12:05:22 - INFO - 	 missing_keys: []
# 03/30/2024 12:05:22 - INFO - 	 unexpected_keys: []
# 03/30/2024 12:05:22 - INFO - 	 mismatched_keys: []
# 03/30/2024 12:05:22 - INFO - 	 error_msgs: []
# 03/30/2024 12:05:22 - INFO - 	 Model Parameters: 90.5M, Transformer: 82.1M, Coref head: 8.4M
# 03/30/2024 12:05:22 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 47.16 examples/s]
# 03/30/2024 12:05:22 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00,  6.15it/s]
# 03/30/2024 12:05:22 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 52.63 examples/s]
# 03/30/2024 12:05:22 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00,  6.18it/s]
# 03/30/2024 12:05:24 - INFO - 	 missing_keys: []
# 03/30/2024 12:05:24 - INFO - 	 unexpected_keys: []
# 03/30/2024 12:05:24 - INFO - 	 mismatched_keys: []
# 03/30/2024 12:05:24 - INFO - 	 error_msgs: []
# 03/30/2024 12:05:24 - INFO - 	 Model Parameters: 90.5M, Transformer: 82.1M, Coref head: 8.4M
# 03/30/2024 12:05:24 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 90.86 examples/s]
# 03/30/2024 12:05:24 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00, 11.72it/s]
# 03/30/2024 12:05:24 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 100.00 examples/s]
# 03/30/2024 12:05:24 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00, 12.46it/s]
# 03/30/2024 12:05:26 - INFO - 	 missing_keys: []
# 03/30/2024 12:05:26 - INFO - 	 unexpected_keys: []
# 03/30/2024 12:05:26 - INFO - 	 mismatched_keys: []
# 03/30/2024 12:05:26 - INFO - 	 error_msgs: []
# 03/30/2024 12:05:26 - INFO - 	 Model Parameters: 90.5M, Transformer: 82.1M, Coref head: 8.4M
# 03/30/2024 12:05:26 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 19.92 examples/s]
# 03/30/2024 12:05:26 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00,  2.69it/s]
# 03/30/2024 12:05:27 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 20.83 examples/s]
# 03/30/2024 12:05:27 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00,  2.75it/s]
# 03/30/2024 12:05:28 - INFO - 	 missing_keys: []
# 03/30/2024 12:05:28 - INFO - 	 unexpected_keys: []
# 03/30/2024 12:05:28 - INFO - 	 mismatched_keys: []
# 03/30/2024 12:05:28 - INFO - 	 error_msgs: []
# 03/30/2024 12:05:28 - INFO - 	 Model Parameters: 90.5M, Transformer: 82.1M, Coref head: 8.4M
# 03/30/2024 12:05:29 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 38.46 examples/s]
# 03/30/2024 12:05:29 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00,  5.56it/s]
# 03/30/2024 12:05:29 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 41.65 examples/s]
# 03/30/2024 12:05:29 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00,  5.81it/s]
# 03/30/2024 12:05:30 - INFO - 	 missing_keys: []
# 03/30/2024 12:05:30 - INFO - 	 unexpected_keys: []
# 03/30/2024 12:05:30 - INFO - 	 mismatched_keys: []
# 03/30/2024 12:05:30 - INFO - 	 error_msgs: []
# 03/30/2024 12:05:30 - INFO - 	 Model Parameters: 90.5M, Transformer: 82.1M, Coref head: 8.4M
# 03/30/2024 12:05:30 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 55.56 examples/s]
# 03/30/2024 12:05:31 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00,  6.98it/s]
# 03/30/2024 12:05:31 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 55.32 examples/s]
# 03/30/2024 12:05:31 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00,  7.15it/s]
# 03/30/2024 12:05:32 - INFO - 	 missing_keys: []
# 03/30/2024 12:05:32 - INFO - 	 unexpected_keys: []
# 03/30/2024 12:05:32 - INFO - 	 mismatched_keys: []
# 03/30/2024 12:05:32 - INFO - 	 error_msgs: []
# 03/30/2024 12:05:32 - INFO - 	 Model Parameters: 90.5M, Transformer: 82.1M, Coref head: 8.4M
# 03/30/2024 12:05:32 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 45.36 examples/s]
# 03/30/2024 12:05:32 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00,  5.85it/s]
# 03/30/2024 12:05:33 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 41.66 examples/s]
# 03/30/2024 12:05:33 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00,  5.59it/s]
# 03/30/2024 12:05:36 - INFO - 	 missing_keys: []
# 03/30/2024 12:05:36 - INFO - 	 unexpected_keys: []
# 03/30/2024 12:05:36 - INFO - 	 mismatched_keys: []
# 03/30/2024 12:05:36 - INFO - 	 error_msgs: []
# 03/30/2024 12:05:36 - INFO - 	 Model Parameters: 90.5M, Transformer: 82.1M, Coref head: 8.4M
# 03/30/2024 12:05:36 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 62.51 examples/s]
# 03/30/2024 12:05:36 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00,  8.39it/s]
# 03/30/2024 12:05:37 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 66.66 examples/s]
# 03/30/2024 12:05:37 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00,  8.44it/s]
# 03/30/2024 12:05:38 - INFO - 	 missing_keys: []
# 03/30/2024 12:05:38 - INFO - 	 unexpected_keys: []
# 03/30/2024 12:05:38 - INFO - 	 mismatched_keys: []
# 03/30/2024 12:05:38 - INFO - 	 error_msgs: []
# 03/30/2024 12:05:38 - INFO - 	 Model Parameters: 90.5M, Transformer: 82.1M, Coref head: 8.4M
# 03/30/2024 12:05:38 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 50.00 examples/s]
# 03/30/2024 12:05:38 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00,  6.13it/s]
# 03/30/2024 12:05:38 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 47.56 examples/s]
# 03/30/2024 12:05:39 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00,  6.53it/s]
# 03/30/2024 12:05:40 - INFO - 	 missing_keys: []
# 03/30/2024 12:05:40 - INFO - 	 unexpected_keys: []
# 03/30/2024 12:05:40 - INFO - 	 mismatched_keys: []
# 03/30/2024 12:05:40 - INFO - 	 error_msgs: []
# 03/30/2024 12:05:40 - INFO - 	 Model Parameters: 90.5M, Transformer: 82.1M, Coref head: 8.4M
# 03/30/2024 12:05:40 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 35.52 examples/s]
# 03/30/2024 12:05:40 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00,  4.06it/s]
# 03/30/2024 12:05:41 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 31.25 examples/s]
# 03/30/2024 12:05:41 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00,  4.85it/s]
# 03/30/2024 12:05:42 - INFO - 	 missing_keys: []
# 03/30/2024 12:05:42 - INFO - 	 unexpected_keys: []
# 03/30/2024 12:05:42 - INFO - 	 mismatched_keys: []
# 03/30/2024 12:05:42 - INFO - 	 error_msgs: []
# 03/30/2024 12:05:42 - INFO - 	 Model Parameters: 90.5M, Transformer: 82.1M, Coref head: 8.4M
# 03/30/2024 12:05:42 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 23.76 examples/s]
# 03/30/2024 12:05:42 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00,  3.10it/s]
# 03/30/2024 12:05:43 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 23.75 examples/s]
# 03/30/2024 12:05:43 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00,  3.27it/s]
# 03/30/2024 12:05:44 - INFO - 	 missing_keys: []
# 03/30/2024 12:05:44 - INFO - 	 unexpected_keys: []
# 03/30/2024 12:05:44 - INFO - 	 mismatched_keys: []
# 03/30/2024 12:05:44 - INFO - 	 error_msgs: []
# 03/30/2024 12:05:44 - INFO - 	 Model Parameters: 90.5M, Transformer: 82.1M, Coref head: 8.4M
# 03/30/2024 12:05:44 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 90.97 examples/s]
# 03/30/2024 12:05:45 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00, 12.41it/s]
# 03/30/2024 12:05:45 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 100.00 examples/s]
# 03/30/2024 12:05:45 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00, 12.29it/s]
# 03/30/2024 12:05:46 - INFO - 	 missing_keys: []
# 03/30/2024 12:05:46 - INFO - 	 unexpected_keys: []
# 03/30/2024 12:05:46 - INFO - 	 mismatched_keys: []
# 03/30/2024 12:05:46 - INFO - 	 error_msgs: []
# 03/30/2024 12:05:46 - INFO - 	 Model Parameters: 90.5M, Transformer: 82.1M, Coref head: 8.4M
# 03/30/2024 12:05:46 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 38.46 examples/s]
# 03/30/2024 12:05:46 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00,  5.35it/s]
# 03/30/2024 12:05:47 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 39.99 examples/s]
# 03/30/2024 12:05:47 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00,  5.46it/s]
# 03/30/2024 12:05:48 - INFO - 	 missing_keys: []
# 03/30/2024 12:05:48 - INFO - 	 unexpected_keys: []
# 03/30/2024 12:05:48 - INFO - 	 mismatched_keys: []
# 03/30/2024 12:05:48 - INFO - 	 error_msgs: []
# 03/30/2024 12:05:48 - INFO - 	 Model Parameters: 90.5M, Transformer: 82.1M, Coref head: 8.4M
# 03/30/2024 12:05:48 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 35.71 examples/s]
# 03/30/2024 12:05:48 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00,  5.00it/s]
# 03/30/2024 12:05:48 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 38.46 examples/s]
# 03/30/2024 12:05:49 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00,  4.87it/s]
# 03/30/2024 12:05:50 - INFO - 	 missing_keys: []
# 03/30/2024 12:05:50 - INFO - 	 unexpected_keys: []
# 03/30/2024 12:05:50 - INFO - 	 mismatched_keys: []
# 03/30/2024 12:05:50 - INFO - 	 error_msgs: []
# 03/30/2024 12:05:50 - INFO - 	 Model Parameters: 90.5M, Transformer: 82.1M, Coref head: 8.4M
# 03/30/2024 12:05:50 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 21.74 examples/s]
# 03/30/2024 12:05:50 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00,  2.73it/s]
# 03/30/2024 12:05:51 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 23.25 examples/s]
# 03/30/2024 12:05:51 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00,  2.76it/s]
# 03/30/2024 12:05:52 - INFO - 	 missing_keys: []
# 03/30/2024 12:05:52 - INFO - 	 unexpected_keys: []
# 03/30/2024 12:05:52 - INFO - 	 mismatched_keys: []
# 03/30/2024 12:05:52 - INFO - 	 error_msgs: []
# 03/30/2024 12:05:52 - INFO - 	 Model Parameters: 90.5M, Transformer: 82.1M, Coref head: 8.4M
# 03/30/2024 12:05:52 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 71.42 examples/s]
# 03/30/2024 12:05:53 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00,  8.81it/s]
# 03/30/2024 12:05:53 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 66.63 examples/s]
# 03/30/2024 12:05:53 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00,  9.27it/s]
# 03/30/2024 12:05:54 - INFO - 	 missing_keys: []
# 03/30/2024 12:05:54 - INFO - 	 unexpected_keys: []
# 03/30/2024 12:05:54 - INFO - 	 mismatched_keys: []
# 03/30/2024 12:05:54 - INFO - 	 error_msgs: []
# 03/30/2024 12:05:54 - INFO - 	 Model Parameters: 90.5M, Transformer: 82.1M, Coref head: 8.4M
# 03/30/2024 12:05:54 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 27.77 examples/s]
# 03/30/2024 12:05:54 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00,  4.33it/s]
# 03/30/2024 12:05:55 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 30.30 examples/s]
# 03/30/2024 12:05:55 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00,  4.13it/s]
# 03/30/2024 12:05:59 - INFO - 	 missing_keys: []
# 03/30/2024 12:05:59 - INFO - 	 unexpected_keys: []
# 03/30/2024 12:05:59 - INFO - 	 mismatched_keys: []
# 03/30/2024 12:05:59 - INFO - 	 error_msgs: []
# 03/30/2024 12:05:59 - INFO - 	 Model Parameters: 90.5M, Transformer: 82.1M, Coref head: 8.4M
# 03/30/2024 12:05:59 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 31.26 examples/s]
# 03/30/2024 12:05:59 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00,  5.09it/s]
# 03/30/2024 12:05:59 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 34.48 examples/s]
# 03/30/2024 12:05:59 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00,  5.08it/s]
# 03/30/2024 12:06:01 - INFO - 	 missing_keys: []
# 03/30/2024 12:06:01 - INFO - 	 unexpected_keys: []
# 03/30/2024 12:06:01 - INFO - 	 mismatched_keys: []
# 03/30/2024 12:06:01 - INFO - 	 error_msgs: []
# 03/30/2024 12:06:01 - INFO - 	 Model Parameters: 90.5M, Transformer: 82.1M, Coref head: 8.4M
# 03/30/2024 12:06:01 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 34.49 examples/s]
# 03/30/2024 12:06:01 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00,  4.60it/s]
# 03/30/2024 12:06:01 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 37.04 examples/s]
# 03/30/2024 12:06:01 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00,  4.78it/s]
# 03/30/2024 12:06:03 - INFO - 	 missing_keys: []
# 03/30/2024 12:06:03 - INFO - 	 unexpected_keys: []
# 03/30/2024 12:06:03 - INFO - 	 mismatched_keys: []
# 03/30/2024 12:06:03 - INFO - 	 error_msgs: []
# 03/30/2024 12:06:03 - INFO - 	 Model Parameters: 90.5M, Transformer: 82.1M, Coref head: 8.4M
# 03/30/2024 12:06:03 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 26.32 examples/s]
# 03/30/2024 12:06:03 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00,  3.67it/s]
# 03/30/2024 12:06:03 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 27.03 examples/s]
# 03/30/2024 12:06:03 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00,  3.72it/s]
# 03/30/2024 12:06:05 - INFO - 	 missing_keys: []
# 03/30/2024 12:06:05 - INFO - 	 unexpected_keys: []
# 03/30/2024 12:06:05 - INFO - 	 mismatched_keys: []
# 03/30/2024 12:06:05 - INFO - 	 error_msgs: []
# 03/30/2024 12:06:05 - INFO - 	 Model Parameters: 90.5M, Transformer: 82.1M, Coref head: 8.4M
# 03/30/2024 12:06:05 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 27.78 examples/s]
# 03/30/2024 12:06:05 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00,  4.09it/s]
# 03/30/2024 12:06:05 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 28.57 examples/s]
# 03/30/2024 12:06:05 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00,  4.12it/s]
# 03/30/2024 12:06:07 - INFO - 	 missing_keys: []
# 03/30/2024 12:06:07 - INFO - 	 unexpected_keys: []
# 03/30/2024 12:06:07 - INFO - 	 mismatched_keys: []
# 03/30/2024 12:06:07 - INFO - 	 error_msgs: []
# 03/30/2024 12:06:07 - INFO - 	 Model Parameters: 90.5M, Transformer: 82.1M, Coref head: 8.4M
# 03/30/2024 12:06:07 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 27.03 examples/s]
# 03/30/2024 12:06:07 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00,  3.37it/s]
# 03/30/2024 12:06:08 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 27.14 examples/s]
# 03/30/2024 12:06:08 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00,  3.63it/s]
# 03/30/2024 12:06:10 - INFO - 	 missing_keys: []
# 03/30/2024 12:06:10 - INFO - 	 unexpected_keys: []
# 03/30/2024 12:06:10 - INFO - 	 mismatched_keys: []
# 03/30/2024 12:06:10 - INFO - 	 error_msgs: []
# 03/30/2024 12:06:10 - INFO - 	 Model Parameters: 90.5M, Transformer: 82.1M, Coref head: 8.4M
# 03/30/2024 12:06:10 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 50.00 examples/s]
# 03/30/2024 12:06:10 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00,  6.33it/s]
# 03/30/2024 12:06:10 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 52.55 examples/s]
# 03/30/2024 12:06:10 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00,  7.50it/s]
# 03/30/2024 12:06:11 - INFO - 	 missing_keys: []
# 03/30/2024 12:06:11 - INFO - 	 unexpected_keys: []
# 03/30/2024 12:06:11 - INFO - 	 mismatched_keys: []
# 03/30/2024 12:06:11 - INFO - 	 error_msgs: []
# 03/30/2024 12:06:11 - INFO - 	 Model Parameters: 90.5M, Transformer: 82.1M, Coref head: 8.4M
# 03/30/2024 12:06:11 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 47.62 examples/s]
# 03/30/2024 12:06:12 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00,  6.52it/s]
# 03/30/2024 12:06:12 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 50.00 examples/s]
# 03/30/2024 12:06:12 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00,  6.59it/s]
# 03/30/2024 12:06:13 - INFO - 	 missing_keys: []
# 03/30/2024 12:06:13 - INFO - 	 unexpected_keys: []
# 03/30/2024 12:06:13 - INFO - 	 mismatched_keys: []
# 03/30/2024 12:06:13 - INFO - 	 error_msgs: []
# 03/30/2024 12:06:13 - INFO - 	 Model Parameters: 90.5M, Transformer: 82.1M, Coref head: 8.4M
# 03/30/2024 12:06:13 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 71.39 examples/s]
# 03/30/2024 12:06:13 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00,  7.29it/s]
# 03/30/2024 12:06:14 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 70.33 examples/s]
# 03/30/2024 12:06:14 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00,  8.01it/s]
# 03/30/2024 12:06:15 - INFO - 	 missing_keys: []
# 03/30/2024 12:06:15 - INFO - 	 unexpected_keys: []
# 03/30/2024 12:06:15 - INFO - 	 mismatched_keys: []
# 03/30/2024 12:06:15 - INFO - 	 error_msgs: []
# 03/30/2024 12:06:15 - INFO - 	 Model Parameters: 90.5M, Transformer: 82.1M, Coref head: 8.4M
# 03/30/2024 12:06:15 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 43.46 examples/s]
# 03/30/2024 12:06:16 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00,  5.46it/s]
# 03/30/2024 12:06:16 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 43.58 examples/s]
# 03/30/2024 12:06:16 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00,  5.88it/s]
# 03/30/2024 12:06:17 - INFO - 	 missing_keys: []
# 03/30/2024 12:06:17 - INFO - 	 unexpected_keys: []
# 03/30/2024 12:06:17 - INFO - 	 mismatched_keys: []
# 03/30/2024 12:06:17 - INFO - 	 error_msgs: []
# 03/30/2024 12:06:17 - INFO - 	 Model Parameters: 90.5M, Transformer: 82.1M, Coref head: 8.4M
# 03/30/2024 12:06:17 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 55.10 examples/s]
# 03/30/2024 12:06:17 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00,  7.83it/s]
# 03/30/2024 12:06:18 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 58.83 examples/s]
# 03/30/2024 12:06:18 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00,  7.75it/s]
# 03/30/2024 12:06:21 - INFO - 	 missing_keys: []
# 03/30/2024 12:06:21 - INFO - 	 unexpected_keys: []
# 03/30/2024 12:06:21 - INFO - 	 mismatched_keys: []
# 03/30/2024 12:06:21 - INFO - 	 error_msgs: []
# 03/30/2024 12:06:21 - INFO - 	 Model Parameters: 90.5M, Transformer: 82.1M, Coref head: 8.4M
# 03/30/2024 12:06:21 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 90.91 examples/s]
# 03/30/2024 12:06:21 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00, 15.13it/s]
# 03/30/2024 12:06:21 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 90.90 examples/s]
# 03/30/2024 12:06:22 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00, 14.87it/s]
# 03/30/2024 12:06:23 - INFO - 	 missing_keys: []
# 03/30/2024 12:06:23 - INFO - 	 unexpected_keys: []
# 03/30/2024 12:06:23 - INFO - 	 mismatched_keys: []
# 03/30/2024 12:06:23 - INFO - 	 error_msgs: []
# 03/30/2024 12:06:23 - INFO - 	 Model Parameters: 90.5M, Transformer: 82.1M, Coref head: 8.4M
# 03/30/2024 12:06:23 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 50.00 examples/s]
# 03/30/2024 12:06:23 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00,  6.58it/s]
# 03/30/2024 12:06:23 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 50.00 examples/s]
# 03/30/2024 12:06:23 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00,  6.65it/s]
# 03/30/2024 12:06:25 - INFO - 	 missing_keys: []
# 03/30/2024 12:06:25 - INFO - 	 unexpected_keys: []
# 03/30/2024 12:06:25 - INFO - 	 mismatched_keys: []
# 03/30/2024 12:06:25 - INFO - 	 error_msgs: []
# 03/30/2024 12:06:25 - INFO - 	 Model Parameters: 90.5M, Transformer: 82.1M, Coref head: 8.4M
# 03/30/2024 12:06:25 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 47.62 examples/s]
# ...
# 03/30/2024 13:07:16 - INFO - 	 mismatched_keys: []
# 03/30/2024 13:07:16 - INFO - 	 error_msgs: []
# 03/30/2024 13:07:16 - INFO - 	 Model Parameters: 90.5M, Transformer: 82.1M, Coref head: 8.4M
# 03/30/2024 13:07:16 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 71.87 examples/s]
# 03/30/2024 13:07:17 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00,  9.05it/s]
# 03/30/2024 13:07:17 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 76.92 examples/s]
# 03/30/2024 13:07:19 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00,  9.35it/s]
# 03/30/2024 13:07:21 - INFO - 	 missing_keys: []
# 03/30/2024 13:07:21 - INFO - 	 unexpected_keys: []
# 03/30/2024 13:07:21 - INFO - 	 mismatched_keys: []
# 03/30/2024 13:07:21 - INFO - 	 error_msgs: []
# 03/30/2024 13:07:21 - INFO - 	 Model Parameters: 90.5M, Transformer: 82.1M, Coref head: 8.4M
# 03/30/2024 13:07:21 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 22.04 examples/s]
# 03/30/2024 13:07:23 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00,  2.98it/s]
# 03/30/2024 13:07:23 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 21.28 examples/s]
# 03/30/2024 13:07:25 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00,  2.89it/s]
# 03/30/2024 13:07:27 - INFO - 	 missing_keys: []
# 03/30/2024 13:07:27 - INFO - 	 unexpected_keys: []
# 03/30/2024 13:07:27 - INFO - 	 mismatched_keys: []
# 03/30/2024 13:07:27 - INFO - 	 error_msgs: []
# 03/30/2024 13:07:27 - INFO - 	 Model Parameters: 90.5M, Transformer: 82.1M, Coref head: 8.4M
# 03/30/2024 13:07:27 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 38.52 examples/s]
# 03/30/2024 13:07:29 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00,  5.11it/s]
# 03/30/2024 13:07:29 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 38.15 examples/s]
# 03/30/2024 13:07:31 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00,  5.20it/s]
# 03/30/2024 13:07:33 - INFO - 	 missing_keys: []
# 03/30/2024 13:07:33 - INFO - 	 unexpected_keys: []
# 03/30/2024 13:07:33 - INFO - 	 mismatched_keys: []
# 03/30/2024 13:07:33 - INFO - 	 error_msgs: []
# 03/30/2024 13:07:33 - INFO - 	 Model Parameters: 90.5M, Transformer: 82.1M, Coref head: 8.4M
# 03/30/2024 13:07:33 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 22.22 examples/s]
# 03/30/2024 13:07:35 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00,  2.92it/s]
# 03/30/2024 13:07:35 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 23.25 examples/s]
# 03/30/2024 13:07:37 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00,  3.04it/s]
# 03/30/2024 13:07:39 - INFO - 	 missing_keys: []
# 03/30/2024 13:07:39 - INFO - 	 unexpected_keys: []
# 03/30/2024 13:07:39 - INFO - 	 mismatched_keys: []
# 03/30/2024 13:07:39 - INFO - 	 error_msgs: []
# 03/30/2024 13:07:39 - INFO - 	 Model Parameters: 90.5M, Transformer: 82.1M, Coref head: 8.4M
# 03/30/2024 13:07:39 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 45.45 examples/s]
# 03/30/2024 13:07:41 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00,  6.47it/s]
# 03/30/2024 13:07:41 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 47.85 examples/s]
# 03/30/2024 13:07:43 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00,  6.85it/s]
# 03/30/2024 13:07:45 - INFO - 	 missing_keys: []
# 03/30/2024 13:07:45 - INFO - 	 unexpected_keys: []
# 03/30/2024 13:07:45 - INFO - 	 mismatched_keys: []
# 03/30/2024 13:07:45 - INFO - 	 error_msgs: []
# 03/30/2024 13:07:45 - INFO - 	 Model Parameters: 90.5M, Transformer: 82.1M, Coref head: 8.4M
# 03/30/2024 13:07:45 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 34.48 examples/s]
# 03/30/2024 13:07:47 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00,  3.13it/s]
# 03/30/2024 13:07:47 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 33.33 examples/s]
# 03/30/2024 13:07:49 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00,  4.59it/s]
# 03/30/2024 13:07:51 - INFO - 	 missing_keys: []
# 03/30/2024 13:07:51 - INFO - 	 unexpected_keys: []
# 03/30/2024 13:07:51 - INFO - 	 mismatched_keys: []
# 03/30/2024 13:07:51 - INFO - 	 error_msgs: []
# 03/30/2024 13:07:51 - INFO - 	 Model Parameters: 90.5M, Transformer: 82.1M, Coref head: 8.4M
# 03/30/2024 13:07:51 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 37.04 examples/s]
# 03/30/2024 13:07:53 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00,  5.15it/s]
# 03/30/2024 13:07:53 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 35.84 examples/s]
# 03/30/2024 13:07:55 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00,  5.32it/s]
# 03/30/2024 13:07:57 - INFO - 	 missing_keys: []
# 03/30/2024 13:07:57 - INFO - 	 unexpected_keys: []
# 03/30/2024 13:07:57 - INFO - 	 mismatched_keys: []
# 03/30/2024 13:07:57 - INFO - 	 error_msgs: []
# 03/30/2024 13:07:57 - INFO - 	 Model Parameters: 90.5M, Transformer: 82.1M, Coref head: 8.4M
# 03/30/2024 13:07:57 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 37.02 examples/s]
# 03/30/2024 13:07:58 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00,  5.29it/s]
# 03/30/2024 13:07:59 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 37.04 examples/s]
# 03/30/2024 13:08:00 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00,  5.56it/s]
# 03/30/2024 13:08:03 - INFO - 	 missing_keys: []
# 03/30/2024 13:08:03 - INFO - 	 unexpected_keys: []
# 03/30/2024 13:08:03 - INFO - 	 mismatched_keys: []
# 03/30/2024 13:08:03 - INFO - 	 error_msgs: []
# 03/30/2024 13:08:03 - INFO - 	 Model Parameters: 90.5M, Transformer: 82.1M, Coref head: 8.4M
# 03/30/2024 13:08:03 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 83.30 examples/s]
# 03/30/2024 13:08:04 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00, 10.42it/s]
# 03/30/2024 13:08:05 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 83.33 examples/s]
# 03/30/2024 13:08:06 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00, 11.90it/s]
# 03/30/2024 13:08:08 - INFO - 	 missing_keys: []
# 03/30/2024 13:08:08 - INFO - 	 unexpected_keys: []
# 03/30/2024 13:08:08 - INFO - 	 mismatched_keys: []
# 03/30/2024 13:08:08 - INFO - 	 error_msgs: []
# 03/30/2024 13:08:08 - INFO - 	 Model Parameters: 90.5M, Transformer: 82.1M, Coref head: 8.4M
# 03/30/2024 13:08:08 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 15.63 examples/s]
# 03/30/2024 13:08:10 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00,  2.17it/s]
# 03/30/2024 13:08:11 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 16.39 examples/s]
# 03/30/2024 13:08:12 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00,  2.02it/s]
# 03/30/2024 13:08:18 - INFO - 	 missing_keys: []
# 03/30/2024 13:08:18 - INFO - 	 unexpected_keys: []
# 03/30/2024 13:08:18 - INFO - 	 mismatched_keys: []
# 03/30/2024 13:08:18 - INFO - 	 error_msgs: []
# 03/30/2024 13:08:18 - INFO - 	 Model Parameters: 90.5M, Transformer: 82.1M, Coref head: 8.4M
# 03/30/2024 13:08:18 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 55.56 examples/s]
# 03/30/2024 13:08:20 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00,  6.87it/s]
# 03/30/2024 13:08:20 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 62.50 examples/s]
# 03/30/2024 13:08:21 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00,  8.35it/s]
# 03/30/2024 13:08:23 - INFO - 	 missing_keys: []
# 03/30/2024 13:08:23 - INFO - 	 unexpected_keys: []
# 03/30/2024 13:08:23 - INFO - 	 mismatched_keys: []
# 03/30/2024 13:08:23 - INFO - 	 error_msgs: []
# 03/30/2024 13:08:23 - INFO - 	 Model Parameters: 90.5M, Transformer: 82.1M, Coref head: 8.4M
# 03/30/2024 13:08:24 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 21.74 examples/s]
# 03/30/2024 13:08:25 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00,  3.18it/s]
# 03/30/2024 13:08:26 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 20.84 examples/s]
# 03/30/2024 13:08:27 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00,  3.43it/s]
# 03/30/2024 13:08:30 - INFO - 	 missing_keys: []
# 03/30/2024 13:08:30 - INFO - 	 unexpected_keys: []
# 03/30/2024 13:08:30 - INFO - 	 mismatched_keys: []
# 03/30/2024 13:08:30 - INFO - 	 error_msgs: []
# 03/30/2024 13:08:30 - INFO - 	 Model Parameters: 90.5M, Transformer: 82.1M, Coref head: 8.4M
# 03/30/2024 13:08:30 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 37.05 examples/s]
# 03/30/2024 13:08:32 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00,  3.34it/s]
# 03/30/2024 13:08:32 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 34.84 examples/s]
# 03/30/2024 13:08:34 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00,  4.75it/s]
# 03/30/2024 13:08:36 - INFO - 	 missing_keys: []
# 03/30/2024 13:08:36 - INFO - 	 unexpected_keys: []
# 03/30/2024 13:08:36 - INFO - 	 mismatched_keys: []
# 03/30/2024 13:08:36 - INFO - 	 error_msgs: []
# 03/30/2024 13:08:36 - INFO - 	 Model Parameters: 90.5M, Transformer: 82.1M, Coref head: 8.4M
# 03/30/2024 13:08:36 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 27.02 examples/s]
# 03/30/2024 13:08:37 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00,  4.14it/s]
# 03/30/2024 13:08:38 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 29.41 examples/s]
# 03/30/2024 13:08:39 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00,  4.15it/s]
# 03/30/2024 13:08:42 - INFO - 	 missing_keys: []
# 03/30/2024 13:08:42 - INFO - 	 unexpected_keys: []
# 03/30/2024 13:08:42 - INFO - 	 mismatched_keys: []
# 03/30/2024 13:08:42 - INFO - 	 error_msgs: []
# 03/30/2024 13:08:42 - INFO - 	 Model Parameters: 90.5M, Transformer: 82.1M, Coref head: 8.4M
# 03/30/2024 13:08:42 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 29.41 examples/s]
# 03/30/2024 13:08:43 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00,  3.94it/s]
# 03/30/2024 13:08:44 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 28.57 examples/s]
# 03/30/2024 13:08:46 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00,  4.34it/s]
# 03/30/2024 13:08:48 - INFO - 	 missing_keys: []
# 03/30/2024 13:08:48 - INFO - 	 unexpected_keys: []
# 03/30/2024 13:08:48 - INFO - 	 mismatched_keys: []
# 03/30/2024 13:08:48 - INFO - 	 error_msgs: []
# 03/30/2024 13:08:48 - INFO - 	 Model Parameters: 90.5M, Transformer: 82.1M, Coref head: 8.4M
# 03/30/2024 13:08:48 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 26.96 examples/s]
# 03/30/2024 13:08:49 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00,  4.68it/s]
# 03/30/2024 13:08:50 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 38.43 examples/s]
# 03/30/2024 13:08:51 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00,  5.18it/s]
# 03/30/2024 13:08:53 - INFO - 	 missing_keys: []
# 03/30/2024 13:08:53 - INFO - 	 unexpected_keys: []
# 03/30/2024 13:08:53 - INFO - 	 mismatched_keys: []
# 03/30/2024 13:08:53 - INFO - 	 error_msgs: []
# 03/30/2024 13:08:53 - INFO - 	 Model Parameters: 90.5M, Transformer: 82.1M, Coref head: 8.4M
# 03/30/2024 13:08:53 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 62.50 examples/s]
# 03/30/2024 13:08:55 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00,  7.86it/s]
# 03/30/2024 13:08:55 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 71.43 examples/s]
# 03/30/2024 13:08:57 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00, 10.31it/s]
# 03/30/2024 13:08:59 - INFO - 	 missing_keys: []
# 03/30/2024 13:08:59 - INFO - 	 unexpected_keys: []
# 03/30/2024 13:08:59 - INFO - 	 mismatched_keys: []
# 03/30/2024 13:08:59 - INFO - 	 error_msgs: []
# 03/30/2024 13:08:59 - INFO - 	 Model Parameters: 90.5M, Transformer: 82.1M, Coref head: 8.4M
# 03/30/2024 13:08:59 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 52.63 examples/s]
# 03/30/2024 13:09:01 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00,  6.25it/s]
# 03/30/2024 13:09:01 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 55.56 examples/s]
# 03/30/2024 13:09:03 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00,  7.07it/s]
# 03/30/2024 13:09:05 - INFO - 	 missing_keys: []
# 03/30/2024 13:09:05 - INFO - 	 unexpected_keys: []
# 03/30/2024 13:09:05 - INFO - 	 mismatched_keys: []
# 03/30/2024 13:09:05 - INFO - 	 error_msgs: []
# 03/30/2024 13:09:05 - INFO - 	 Model Parameters: 90.5M, Transformer: 82.1M, Coref head: 8.4M
# 03/30/2024 13:09:05 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 90.97 examples/s]
# 03/30/2024 13:09:07 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00,  9.26it/s]
# 03/30/2024 13:09:07 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 83.28 examples/s]
# 03/30/2024 13:09:09 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00, 14.53it/s]
# 03/30/2024 13:09:11 - INFO - 	 missing_keys: []
# 03/30/2024 13:09:11 - INFO - 	 unexpected_keys: []
# 03/30/2024 13:09:11 - INFO - 	 mismatched_keys: []
# 03/30/2024 13:09:11 - INFO - 	 error_msgs: []
# 03/30/2024 13:09:11 - INFO - 	 Model Parameters: 90.5M, Transformer: 82.1M, Coref head: 8.4M
# 03/30/2024 13:09:11 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00,  8.13 examples/s]
# 03/30/2024 13:09:13 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00,  1.21it/s]
# 03/30/2024 13:09:14 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00,  8.85 examples/s]
# 03/30/2024 13:09:16 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00,  1.15it/s]
# Model: en_core_web_sm
#   Rule-based: F1: 0.6833333333333333, Exact Match: 0.65, Time: 0.31165207624435426 sec
#   BERT: F1: 0.6365079365079365, Exact Match: 0.5, Time: 1.7874438524246217 sec
# Model: en_core_web_trf
#   Rule-based: F1: 0.7833333333333333, Exact Match: 0.75, Time: 1.4920156717300415 sec
#   BERT: F1: 0.6365079365079365, Exact Match: 0.5, Time: 1.759422981739044 sec
# Model: en_core_web_md
#   Rule-based: F1: 0.7833333333333333, Exact Match: 0.75, Time: 0.7362376689910889 sec
#   BERT: F1: 0.6365079365079365, Exact Match: 0.5, Time: 1.8217221975326539 sec
# Model: en_core_web_lg
#   Rule-based: F1: 0.7333333333333333, Exact Match: 0.7, Time: 0.9263777494430542 sec
#   BERT: F1: 0.6365079365079365, Exact Match: 0.5, Time: 1.8769330739974976 sec

# %% [markdown]
# | Model            | Method     | F1                 | Exact Match | Time (sec)          |
# |------------------|------------|--------------------|-------------|---------------------|
# | en_core_web_sm   | Rule-based | 0.6833333333333333 | 0.65        | 0.31165207624435426 |
# | en_core_web_sm   | BERT       | 0.6365079365079365 | 0.5         | 1.7874438524246217  |
# | en_core_web_trf  | Rule-based | 0.7833333333333333 | 0.75        | 1.4920156717300415  |
# | en_core_web_trf  | BERT       | 0.6365079365079365 | 0.5         | 1.759422981739044   |
# | **en_core_web_md**   | **Rule-based** | **0.7833333333333333** | **0.75**        | **0.7362376689910889**  |
# | **en_core_web_md**   | **BERT**       | **0.6365079365079365** | **0.5**         | **1.8217221975326539**  |
# | en_core_web_lg   | Rule-based | 0.7333333333333333 | 0.7         | 0.9263777494430542  |
# | en_core_web_lg   | BERT       | 0.6365079365079365 | 0.5         | 1.8769330739974976  |

# %% [markdown]
# ### 4.5.1 The IR-QA system with "en_core_web_md" model

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.neighbors import NearestNeighbors
from fastcoref import spacy_component
from fastcoref import LingMessCoref
import spacy
from sklearn.metrics.pairwise import cosine_similarity
import numpy as np
import nltk
import torch
from transformers import BertForQuestionAnswering, BertTokenizer


class Information_Retrieval_System:
    def __init__(self, df, question):
        self.df = df
        self.question = question

        self.top_articles = self.article_retrieval(df, question)
        self.resolved_articles = [self.Coreference_Resolution(article) for article in self.top_articles['article']]
        self.most_relevant_sentence, self.similarity = self.text_matching(self.resolved_articles, question)

    
    def article_retrieval(self,df, question):
        tfidf_configs = {
            'lowercase': True,
            'analyzer': 'word',
            'stop_words': 'english',
            'binary': True,
            'max_df': 0.9,
            'max_features': 10_000
        }

        retriever_configs = {
            'n_neighbors': 10, 
            'metric': 'cosine'
        }

        embedding = TfidfVectorizer(**tfidf_configs)
        retriever = NearestNeighbors(**retriever_configs)

        X = embedding.fit_transform(df['article'])
        retriever.fit(X, df['id'].values.reshape(-1, 1))

        X_question = embedding.transform([question])

        distances, indices = retriever.kneighbors(X_question, return_distance=True)

        return df.iloc[indices[0]]
    
    def Coreference_Resolution(self,text):
        nlp = spacy.load("en_core_web_md")
        nlp.add_pipe("fastcoref")
        doc = nlp(text)
        # nlp.add_pipe("fastcoref", config={'model_architecture': 'LingMessCoref', 'model_path': 'biu-nlp/lingmess-coref', 'device': 'cpu'})
        doc = nlp(text, component_cfg={"fastcoref": {'resolve_text': True}})
        return doc._.resolved_text
    
    def text_matching(self,top_articles,question):
        sentences = nltk.sent_tokenize(" ".join(top_articles))
        vectorizer = TfidfVectorizer(stop_words='english')
        combined_text = [question] + sentences
        tfidf_matrix = vectorizer.fit_transform(combined_text)
        cosine_similarities = cosine_similarity(tfidf_matrix[0:1], tfidf_matrix[1:])

        # Find the index of the highest similarity score
        most_similar_sentence_index = cosine_similarities.argmax()

        # Return the most relevant sentence and its similarity score
        return sentences[most_similar_sentence_index], cosine_similarities[0, most_similar_sentence_index]
    
    def Answer_Extraction(self,sentence,similarity,question):
        nlp = spacy.load("en_core_web_md")
        doc = nlp(sentence)
        sample_doc = {i.text:i.label_ for i in doc.ents}
        question = question.lower()
        if similarity > 0.35:
                try:
                    if question.startswith('who'):
                        who_list = [k for k,v in sample_doc.items() if v=='PERSON']
                        return who_list[0] if len (who_list)>0 else 'NO ANSWER'
                    elif question.startswith('where'):
                        where_list = [k for k,v in sample_doc.items() if v=='LOC' or  v=='GPE']
                        return where_list[0] if len (where_list) >0 else 'NO ANSWER'
                    elif question.startswith('when'):
                        when_list = [k for k,v in sample_doc.items() if v=='DATE']
                        return when_list[0] if len (when_list) >0 else 'NO ANSWER'
                    elif question.startswith('what'):
                        what_list = [k for k,v in sample_doc.items() if v=='ORG']
                        return what_list[0] if len (what_list) >0 else 'NO ANSWER'
                    elif question.startswith('how many'):
                        how_many_list = [k for k,v in sample_doc.items() if v=='MONEY' or  v=='DATE']
                        return how_many_list[0] if len (how_many_list) >0 else 'NO ANSWER'
                except:
                    return 'NO ANSWER'
        else:
            return "NO ANSWER"

    def Rule_base(self):
        return self.Answer_Extraction(self.most_relevant_sentence, self.similarity, self.question)

    
    def Bert(self):
        model = BertForQuestionAnswering.from_pretrained('bert-large-uncased-whole-word-masking-finetuned-squad')
        tokenizer = BertTokenizer.from_pretrained('bert-large-uncased-whole-word-masking-finetuned-squad')

        if self.similarity > 0.35:
            input_ids = tokenizer.encode(self.question, self.most_relevant_sentence, max_length=512, truncation=True)

            tokens = tokenizer.convert_ids_to_tokens(input_ids)
            sep_index = input_ids.index(tokenizer.sep_token_id)
            num_seg_a = sep_index + 1
            num_seg_b = len(input_ids) - num_seg_a
            segment_ids = [0]*num_seg_a + [1]*num_seg_b

            model_scores = model.forward(torch.tensor([input_ids]),token_type_ids=torch.tensor([segment_ids]))

            start_scores = model_scores.start_logits
            end_scores = model_scores.end_logits

            answer_start = torch.argmax(start_scores)
            answer_end = torch.argmax(end_scores)

            return ' '.join(tokens[answer_start:answer_end+1])
        else:
            return "NO ANSWER"

# %% [markdown]
# ### 4.5.2 Demonstration of `Information_Retrieval_System`

# %%
question = 'Who is the vice chairman of Samsung?'


ir = Information_Retrieval_System(df_clean,question)
# Out:
# 03/30/2024 14:04:45 - INFO - 	 missing_keys: []
# 03/30/2024 14:04:45 - INFO - 	 unexpected_keys: []
# 03/30/2024 14:04:45 - INFO - 	 mismatched_keys: []
# 03/30/2024 14:04:45 - INFO - 	 error_msgs: []
# 03/30/2024 14:04:45 - INFO - 	 Model Parameters: 90.5M, Transformer: 82.1M, Coref head: 8.4M
# 03/30/2024 14:04:45 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 37.04 examples/s]
# 03/30/2024 14:04:45 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00,  6.37it/s]
# 03/30/2024 14:04:45 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 38.41 examples/s]
# 03/30/2024 14:04:46 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00,  6.51it/s]
# 03/30/2024 14:04:47 - INFO - 	 missing_keys: []
# 03/30/2024 14:04:47 - INFO - 	 unexpected_keys: []
# 03/30/2024 14:04:47 - INFO - 	 mismatched_keys: []
# 03/30/2024 14:04:47 - INFO - 	 error_msgs: []
# 03/30/2024 14:04:47 - INFO - 	 Model Parameters: 90.5M, Transformer: 82.1M, Coref head: 8.4M
# 03/30/2024 14:04:47 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 38.46 examples/s]
# 03/30/2024 14:04:48 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00,  6.82it/s]
# 03/30/2024 14:04:48 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 37.05 examples/s]
# 03/30/2024 14:04:48 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00,  6.79it/s]
# 03/30/2024 14:04:50 - INFO - 	 missing_keys: []
# 03/30/2024 14:04:50 - INFO - 	 unexpected_keys: []
# 03/30/2024 14:04:50 - INFO - 	 mismatched_keys: []
# 03/30/2024 14:04:50 - INFO - 	 error_msgs: []
# 03/30/2024 14:04:50 - INFO - 	 Model Parameters: 90.5M, Transformer: 82.1M, Coref head: 8.4M
# 03/30/2024 14:04:50 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 25.63 examples/s]
# 03/30/2024 14:04:51 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00,  4.81it/s]
# 03/30/2024 14:04:51 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 27.03 examples/s]
# 03/30/2024 14:04:51 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00,  4.78it/s]
# 03/30/2024 14:04:53 - INFO - 	 missing_keys: []
# 03/30/2024 14:04:53 - INFO - 	 unexpected_keys: []
# 03/30/2024 14:04:53 - INFO - 	 mismatched_keys: []
# 03/30/2024 14:04:53 - INFO - 	 error_msgs: []
# 03/30/2024 14:04:53 - INFO - 	 Model Parameters: 90.5M, Transformer: 82.1M, Coref head: 8.4M
# 03/30/2024 14:04:53 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 26.31 examples/s]
# 03/30/2024 14:04:54 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00,  4.17it/s]
# 03/30/2024 14:04:54 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 28.15 examples/s]
# 03/30/2024 14:04:54 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00,  4.22it/s]
# 03/30/2024 14:04:56 - INFO - 	 missing_keys: []
# 03/30/2024 14:04:56 - INFO - 	 unexpected_keys: []
# 03/30/2024 14:04:56 - INFO - 	 mismatched_keys: []
# 03/30/2024 14:04:56 - INFO - 	 error_msgs: []
# 03/30/2024 14:04:56 - INFO - 	 Model Parameters: 90.5M, Transformer: 82.1M, Coref head: 8.4M
# 03/30/2024 14:04:56 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 27.03 examples/s]
# 03/30/2024 14:04:57 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00,  3.95it/s]
# 03/30/2024 14:04:57 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 27.02 examples/s]
# 03/30/2024 14:04:58 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00,  3.81it/s]
# 03/30/2024 14:04:59 - INFO - 	 missing_keys: []
# 03/30/2024 14:04:59 - INFO - 	 unexpected_keys: []
# 03/30/2024 14:04:59 - INFO - 	 mismatched_keys: []
# 03/30/2024 14:04:59 - INFO - 	 error_msgs: []
# 03/30/2024 14:04:59 - INFO - 	 Model Parameters: 90.5M, Transformer: 82.1M, Coref head: 8.4M
# 03/30/2024 14:04:59 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 83.28 examples/s]
# 03/30/2024 14:05:00 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00, 14.02it/s]
# 03/30/2024 14:05:00 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 90.81 examples/s]
# 03/30/2024 14:05:00 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00, 13.71it/s]
# 03/30/2024 14:05:02 - INFO - 	 missing_keys: []
# 03/30/2024 14:05:02 - INFO - 	 unexpected_keys: []
# 03/30/2024 14:05:02 - INFO - 	 mismatched_keys: []
# 03/30/2024 14:05:02 - INFO - 	 error_msgs: []
# 03/30/2024 14:05:02 - INFO - 	 Model Parameters: 90.5M, Transformer: 82.1M, Coref head: 8.4M
# 03/30/2024 14:05:02 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 27.03 examples/s]
# 03/30/2024 14:05:03 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00,  4.28it/s]
# 03/30/2024 14:05:03 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 27.02 examples/s]
# 03/30/2024 14:05:03 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00,  3.99it/s]
# 03/30/2024 14:05:05 - INFO - 	 missing_keys: []
# 03/30/2024 14:05:05 - INFO - 	 unexpected_keys: []
# 03/30/2024 14:05:05 - INFO - 	 mismatched_keys: []
# 03/30/2024 14:05:05 - INFO - 	 error_msgs: []
# 03/30/2024 14:05:05 - INFO - 	 Model Parameters: 90.5M, Transformer: 82.1M, Coref head: 8.4M
# 03/30/2024 14:05:05 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 25.47 examples/s]
# 03/30/2024 14:05:06 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00,  4.12it/s]
# 03/30/2024 14:05:06 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 26.31 examples/s]
# 03/30/2024 14:05:06 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00,  4.05it/s]
# 03/30/2024 14:05:09 - INFO - 	 missing_keys: []
# 03/30/2024 14:05:09 - INFO - 	 unexpected_keys: []
# 03/30/2024 14:05:09 - INFO - 	 mismatched_keys: []
# 03/30/2024 14:05:09 - INFO - 	 error_msgs: []
# 03/30/2024 14:05:09 - INFO - 	 Model Parameters: 90.5M, Transformer: 82.1M, Coref head: 8.4M
# 03/30/2024 14:05:09 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 58.79 examples/s]
# 03/30/2024 14:05:09 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00,  8.70it/s]
# 03/30/2024 14:05:09 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 55.54 examples/s]
# 03/30/2024 14:05:10 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00,  9.09it/s]
# 03/30/2024 14:05:12 - INFO - 	 missing_keys: []
# 03/30/2024 14:05:12 - INFO - 	 unexpected_keys: []
# 03/30/2024 14:05:12 - INFO - 	 mismatched_keys: []
# 03/30/2024 14:05:12 - INFO - 	 error_msgs: []
# 03/30/2024 14:05:12 - INFO - 	 Model Parameters: 90.5M, Transformer: 82.1M, Coref head: 8.4M
# 03/30/2024 14:05:12 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 11.76 examples/s]
# 03/30/2024 14:05:12 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00,  1.95it/s]
# 03/30/2024 14:05:13 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 12.33 examples/s]
# 03/30/2024 14:05:14 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00,  1.94it/s]

# %%
print(ir.Rule_base())
print(ir.Bert())
# Out:
# Jay Y. Lee
# jay y . lee

# %% [markdown]
# ## 5. Testing

# %% [markdown]
# ### 5.1 The evaluation function for IR-QA system

# %%
import pandas as pd
import time

def evaluate_information_retrieval_system(df, questions, answers):
    rule_based_exact_matches = []
    rule_based_f1_scores = []
    bert_exact_matches = []
    bert_f1_scores = []
    
    rule_based_timings = []
    bert_timings = []

    for question, true_answer in zip(questions, answers):
        # Initialize the Information Retrieval System for each question
        ir_system = Information_Retrieval_System(df, question)
        
        # Rule-based answer retrieval and timing
        start_time = time.time()
        rule_based_answer = ir_system.Rule_base()
        end_time = time.time()
        rule_based_timings.append(end_time - start_time)
        
        # Compute Exact Match and F1 score for Rule-based method
        rule_based_exact_matches.append(compute_exact(true_answer, rule_based_answer))
        rule_based_f1_scores.append(compute_f1(true_answer, rule_based_answer))
        
        # BERT answer retrieval and timing
        start_time = time.time()
        bert_answer = ir_system.Bert()
        end_time = time.time()
        bert_timings.append(end_time - start_time)
        
        # Compute Exact Match and F1 score for BERT method
        bert_exact_matches.append(compute_exact(true_answer, bert_answer))
        bert_f1_scores.append(compute_f1(true_answer, bert_answer))
    
    # Calculate and return the average Exact Match, F1 scores, and timings for both methods
    avg_rule_based_exact_match = sum(rule_based_exact_matches) / len(rule_based_exact_matches)
    avg_rule_based_f1 = sum(rule_based_f1_scores) / len(rule_based_f1_scores)
    avg_bert_exact_match = sum(bert_exact_matches) / len(bert_exact_matches)
    avg_bert_f1 = sum(bert_f1_scores) / len(bert_f1_scores)
    avg_rule_based_time = sum(rule_based_timings) / len(rule_based_timings)
    avg_bert_time = sum(bert_timings) / len(bert_timings)
    
    return {
        "Rule-based": {"Exact Match": avg_rule_based_exact_match, "F1": avg_rule_based_f1, "Avg Time (s)": avg_rule_based_time},
        "BERT": {"Exact Match": avg_bert_exact_match, "F1": avg_bert_f1, "Avg Time (s)": avg_bert_time}
    }

# %% [markdown]
# ### 5.2 SQuAD Dev Set for Testing
#
# The Stanford Question Answering Dataset (SQuAD) Dev v2.0, a benchmark in reading comprehension, was employed to test the system's proficiency in handling real-world data. It required converting the dataset from JSON to a more manageable data frame format, enabling a structured testing environment where each article's first question and answer were extracted to assess the system's effectiveness in understanding and responding to varied queries (The Stanford NLP Group 2024).

# %%
test_data = pd.read_json("dev-v2.0.json")

dataset = []

for i in range(len(test_data["data"])):
    for e in range(len(test_data["data"][i]["paragraphs"])):
        data_dict = {}
        data_dict["id"] = test_data["data"][i]["paragraphs"][e]["qas"][0]["id"]
        data_dict["article"] = test_data["data"][i]["paragraphs"][e]["context"]
        data_dict["question"] = test_data["data"][i]["paragraphs"][e]["qas"][0]["question"]
        data_dict["answer"] = test_data["data"][i]["paragraphs"][e]["qas"][0]["answers"][0]["text"]
        dataset.append(data_dict)

test_df = pd.DataFrame(dataset)[0:500]

test_df.head()
# Out:
#                          id  \
# 0  56ddde6b9a695914005b9628
# 1  56dddf4066d3e219004dad5f
# 2  56dde0379a695914005b9636
# 3  56dde0ba66d3e219004dad75
# 4  56dde1d966d3e219004dad8d
#
#                                              article  \
# 0  The Normans (Norman: Nourmands; French: Norman...
# 1  The Norman dynasty had a major political, cult...
# 2  The English name "Normans" comes from the Fren...
# 3  In the course of the 10th century, the initial...
# 4  Before Rollo's arrival, its populations did no...
#
#                                             question                 answer
# 0               In what country is Normandy located?                 France
# 1        Who was the duke in the battle of Hastings?  William the Conqueror
# 2   What is the original meaning of the word Norman?                 Viking
# 3            When was the Duchy of Normandy founded?                    911
# 4  Who upon arriving gave the original viking set...                  Rollo

# %%
index = 254
squad_df = test_df[index-20:index]
squad_question = squad_df["question"]
squad_answer = squad_df["answer"]

evaluate_information_retrieval_system(test_df,squad_question, squad_answer)
# Out:
# 03/29/2024 13:50:20 - INFO - 	 missing_keys: []
# 03/29/2024 13:50:20 - INFO - 	 unexpected_keys: []
# 03/29/2024 13:50:20 - INFO - 	 mismatched_keys: []
# 03/29/2024 13:50:20 - INFO - 	 error_msgs: []
# 03/29/2024 13:50:20 - INFO - 	 Model Parameters: 90.5M, Transformer: 82.1M, Coref head: 8.4M
# 03/29/2024 13:50:20 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 166.69 examples/s]
# 03/29/2024 13:50:20 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00, 26.25it/s]
# 03/29/2024 13:50:20 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 166.47 examples/s]
# 03/29/2024 13:50:20 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00, 27.02it/s]
# 03/29/2024 13:50:21 - INFO - 	 missing_keys: []
# 03/29/2024 13:50:21 - INFO - 	 unexpected_keys: []
# 03/29/2024 13:50:21 - INFO - 	 mismatched_keys: []
# 03/29/2024 13:50:21 - INFO - 	 error_msgs: []
# 03/29/2024 13:50:21 - INFO - 	 Model Parameters: 90.5M, Transformer: 82.1M, Coref head: 8.4M
# 03/29/2024 13:50:21 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 142.60 examples/s]
# 03/29/2024 13:50:22 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00, 22.80it/s]
# 03/29/2024 13:50:22 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 166.65 examples/s]
# 03/29/2024 13:50:22 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00, 23.85it/s]
# 03/29/2024 13:50:23 - INFO - 	 missing_keys: []
# 03/29/2024 13:50:23 - INFO - 	 unexpected_keys: []
# 03/29/2024 13:50:23 - INFO - 	 mismatched_keys: []
# 03/29/2024 13:50:23 - INFO - 	 error_msgs: []
# 03/29/2024 13:50:23 - INFO - 	 Model Parameters: 90.5M, Transformer: 82.1M, Coref head: 8.4M
# 03/29/2024 13:50:23 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 166.67 examples/s]
# 03/29/2024 13:50:23 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00, 29.41it/s]
# 03/29/2024 13:50:23 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 145.44 examples/s]
# 03/29/2024 13:50:23 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00, 31.23it/s]
# 03/29/2024 13:50:25 - INFO - 	 missing_keys: []
# 03/29/2024 13:50:25 - INFO - 	 unexpected_keys: []
# 03/29/2024 13:50:25 - INFO - 	 mismatched_keys: []
# 03/29/2024 13:50:25 - INFO - 	 error_msgs: []
# 03/29/2024 13:50:25 - INFO - 	 Model Parameters: 90.5M, Transformer: 82.1M, Coref head: 8.4M
# 03/29/2024 13:50:25 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 166.72 examples/s]
# 03/29/2024 13:50:25 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00, 25.44it/s]
# 03/29/2024 13:50:25 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 166.65 examples/s]
# 03/29/2024 13:50:25 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00, 28.51it/s]
# 03/29/2024 13:50:26 - INFO - 	 missing_keys: []
# 03/29/2024 13:50:26 - INFO - 	 unexpected_keys: []
# 03/29/2024 13:50:26 - INFO - 	 mismatched_keys: []
# 03/29/2024 13:50:26 - INFO - 	 error_msgs: []
# 03/29/2024 13:50:26 - INFO - 	 Model Parameters: 90.5M, Transformer: 82.1M, Coref head: 8.4M
# 03/29/2024 13:50:26 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 142.85 examples/s]
# 03/29/2024 13:50:26 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00, 26.06it/s]
# 03/29/2024 13:50:26 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 166.69 examples/s]
# 03/29/2024 13:50:26 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00, 26.46it/s]
# 03/29/2024 13:50:28 - INFO - 	 missing_keys: []
# 03/29/2024 13:50:28 - INFO - 	 unexpected_keys: []
# 03/29/2024 13:50:28 - INFO - 	 mismatched_keys: []
# 03/29/2024 13:50:28 - INFO - 	 error_msgs: []
# 03/29/2024 13:50:28 - INFO - 	 Model Parameters: 90.5M, Transformer: 82.1M, Coref head: 8.4M
# 03/29/2024 13:50:28 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 166.75 examples/s]
# 03/29/2024 13:50:28 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00, 21.99it/s]
# 03/29/2024 13:50:28 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 142.68 examples/s]
# 03/29/2024 13:50:28 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00, 20.99it/s]
# 03/29/2024 13:50:29 - INFO - 	 missing_keys: []
# 03/29/2024 13:50:29 - INFO - 	 unexpected_keys: []
# 03/29/2024 13:50:29 - INFO - 	 mismatched_keys: []
# 03/29/2024 13:50:29 - INFO - 	 error_msgs: []
# 03/29/2024 13:50:29 - INFO - 	 Model Parameters: 90.5M, Transformer: 82.1M, Coref head: 8.4M
# 03/29/2024 13:50:29 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 142.86 examples/s]
# 03/29/2024 13:50:29 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00, 19.95it/s]
# 03/29/2024 13:50:29 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 125.01 examples/s]
# 03/29/2024 13:50:29 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00, 19.96it/s]
# 03/29/2024 13:50:31 - INFO - 	 missing_keys: []
# 03/29/2024 13:50:31 - INFO - 	 unexpected_keys: []
# 03/29/2024 13:50:31 - INFO - 	 mismatched_keys: []
# 03/29/2024 13:50:31 - INFO - 	 error_msgs: []
# 03/29/2024 13:50:31 - INFO - 	 Model Parameters: 90.5M, Transformer: 82.1M, Coref head: 8.4M
# 03/29/2024 13:50:31 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 142.86 examples/s]
# 03/29/2024 13:50:31 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00, 20.84it/s]
# 03/29/2024 13:50:31 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 166.55 examples/s]
# 03/29/2024 13:50:31 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00, 23.61it/s]
# 03/29/2024 13:50:33 - INFO - 	 missing_keys: []
# 03/29/2024 13:50:33 - INFO - 	 unexpected_keys: []
# 03/29/2024 13:50:33 - INFO - 	 mismatched_keys: []
# 03/29/2024 13:50:33 - INFO - 	 error_msgs: []
# 03/29/2024 13:50:33 - INFO - 	 Model Parameters: 90.5M, Transformer: 82.1M, Coref head: 8.4M
# 03/29/2024 13:50:33 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 166.71 examples/s]
# 03/29/2024 13:50:33 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00, 29.87it/s]
# 03/29/2024 13:50:33 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 200.09 examples/s]
# 03/29/2024 13:50:33 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00, 28.46it/s]
# 03/29/2024 13:50:34 - INFO - 	 missing_keys: []
# 03/29/2024 13:50:34 - INFO - 	 unexpected_keys: []
# 03/29/2024 13:50:34 - INFO - 	 mismatched_keys: []
# 03/29/2024 13:50:34 - INFO - 	 error_msgs: []
# 03/29/2024 13:50:34 - INFO - 	 Model Parameters: 90.5M, Transformer: 82.1M, Coref head: 8.4M
# 03/29/2024 13:50:34 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 166.70 examples/s]
# 03/29/2024 13:50:34 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00, 27.78it/s]
# 03/29/2024 13:50:34 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 166.69 examples/s]
# 03/29/2024 13:50:34 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00, 25.00it/s]
# 03/29/2024 13:50:39 - INFO - 	 missing_keys: []
# 03/29/2024 13:50:39 - INFO - 	 unexpected_keys: []
# 03/29/2024 13:50:39 - INFO - 	 mismatched_keys: []
# 03/29/2024 13:50:39 - INFO - 	 error_msgs: []
# 03/29/2024 13:50:39 - INFO - 	 Model Parameters: 90.5M, Transformer: 82.1M, Coref head: 8.4M
# 03/29/2024 13:50:39 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 166.92 examples/s]
# 03/29/2024 13:50:39 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00, 23.65it/s]
# 03/29/2024 13:50:39 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 166.48 examples/s]
# 03/29/2024 13:50:39 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00, 24.70it/s]
# 03/29/2024 13:50:40 - INFO - 	 missing_keys: []
# 03/29/2024 13:50:40 - INFO - 	 unexpected_keys: []
# 03/29/2024 13:50:40 - INFO - 	 mismatched_keys: []
# 03/29/2024 13:50:40 - INFO - 	 error_msgs: []
# 03/29/2024 13:50:40 - INFO - 	 Model Parameters: 90.5M, Transformer: 82.1M, Coref head: 8.4M
# 03/29/2024 13:50:40 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 166.50 examples/s]
# 03/29/2024 13:50:41 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00, 27.78it/s]
# 03/29/2024 13:50:41 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 166.70 examples/s]
# 03/29/2024 13:50:41 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00, 27.62it/s]
# 03/29/2024 13:50:42 - INFO - 	 missing_keys: []
# 03/29/2024 13:50:42 - INFO - 	 unexpected_keys: []
# 03/29/2024 13:50:42 - INFO - 	 mismatched_keys: []
# 03/29/2024 13:50:42 - INFO - 	 error_msgs: []
# 03/29/2024 13:50:42 - INFO - 	 Model Parameters: 90.5M, Transformer: 82.1M, Coref head: 8.4M
# 03/29/2024 13:50:42 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 142.69 examples/s]
# 03/29/2024 13:50:43 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00, 22.77it/s]
# 03/29/2024 13:50:43 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 166.42 examples/s]
# 03/29/2024 13:50:43 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00, 20.36it/s]
# 03/29/2024 13:50:44 - INFO - 	 missing_keys: []
# 03/29/2024 13:50:44 - INFO - 	 unexpected_keys: []
# 03/29/2024 13:50:44 - INFO - 	 mismatched_keys: []
# 03/29/2024 13:50:44 - INFO - 	 error_msgs: []
# 03/29/2024 13:50:44 - INFO - 	 Model Parameters: 90.5M, Transformer: 82.1M, Coref head: 8.4M
# 03/29/2024 13:50:44 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 166.88 examples/s]
# 03/29/2024 13:50:44 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00, 26.41it/s]
# 03/29/2024 13:50:44 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 199.99 examples/s]
# 03/29/2024 13:50:44 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00, 28.56it/s]
# 03/29/2024 13:50:45 - INFO - 	 missing_keys: []
# 03/29/2024 13:50:45 - INFO - 	 unexpected_keys: []
# 03/29/2024 13:50:45 - INFO - 	 mismatched_keys: []
# 03/29/2024 13:50:45 - INFO - 	 error_msgs: []
# 03/29/2024 13:50:45 - INFO - 	 Model Parameters: 90.5M, Transformer: 82.1M, Coref head: 8.4M
# 03/29/2024 13:50:45 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 199.79 examples/s]
# 03/29/2024 13:50:46 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00, 29.72it/s]
# 03/29/2024 13:50:46 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 199.71 examples/s]
# 03/29/2024 13:50:46 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00, 29.11it/s]
# 03/29/2024 13:50:47 - INFO - 	 missing_keys: []
# 03/29/2024 13:50:47 - INFO - 	 unexpected_keys: []
# 03/29/2024 13:50:47 - INFO - 	 mismatched_keys: []
# 03/29/2024 13:50:47 - INFO - 	 error_msgs: []
# 03/29/2024 13:50:47 - INFO - 	 Model Parameters: 90.5M, Transformer: 82.1M, Coref head: 8.4M
# 03/29/2024 13:50:47 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 199.70 examples/s]
# 03/29/2024 13:50:47 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00, 26.19it/s]
# 03/29/2024 13:50:47 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 166.67 examples/s]
# 03/29/2024 13:50:47 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00, 29.16it/s]
# 03/29/2024 13:50:49 - INFO - 	 missing_keys: []
# 03/29/2024 13:50:49 - INFO - 	 unexpected_keys: []
# 03/29/2024 13:50:49 - INFO - 	 mismatched_keys: []
# 03/29/2024 13:50:49 - INFO - 	 error_msgs: []
# 03/29/2024 13:50:49 - INFO - 	 Model Parameters: 90.5M, Transformer: 82.1M, Coref head: 8.4M
# 03/29/2024 13:50:49 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 142.86 examples/s]
# 03/29/2024 13:50:49 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00, 12.37it/s]
# 03/29/2024 13:50:49 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 125.12 examples/s]
# 03/29/2024 13:50:49 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00, 23.26it/s]
# 03/29/2024 13:50:50 - INFO - 	 missing_keys: []
# 03/29/2024 13:50:50 - INFO - 	 unexpected_keys: []
# 03/29/2024 13:50:50 - INFO - 	 mismatched_keys: []
# 03/29/2024 13:50:50 - INFO - 	 error_msgs: []
# 03/29/2024 13:50:50 - INFO - 	 Model Parameters: 90.5M, Transformer: 82.1M, Coref head: 8.4M
# 03/29/2024 13:50:50 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 143.03 examples/s]
# 03/29/2024 13:50:50 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00, 20.41it/s]
# 03/29/2024 13:50:50 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 142.70 examples/s]
# 03/29/2024 13:50:51 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00, 20.06it/s]
# 03/29/2024 13:50:52 - INFO - 	 missing_keys: []
# 03/29/2024 13:50:52 - INFO - 	 unexpected_keys: []
# 03/29/2024 13:50:52 - INFO - 	 mismatched_keys: []
# 03/29/2024 13:50:52 - INFO - 	 error_msgs: []
# 03/29/2024 13:50:52 - INFO - 	 Model Parameters: 90.5M, Transformer: 82.1M, Coref head: 8.4M
# 03/29/2024 13:50:52 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 166.67 examples/s]
# 03/29/2024 13:50:52 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00, 25.07it/s]
# 03/29/2024 13:50:52 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 142.85 examples/s]
# 03/29/2024 13:50:52 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00, 26.58it/s]
# 03/29/2024 13:50:53 - INFO - 	 missing_keys: []
# 03/29/2024 13:50:53 - INFO - 	 unexpected_keys: []
# 03/29/2024 13:50:53 - INFO - 	 mismatched_keys: []
# 03/29/2024 13:50:53 - INFO - 	 error_msgs: []
# 03/29/2024 13:50:53 - INFO - 	 Model Parameters: 90.5M, Transformer: 82.1M, Coref head: 8.4M
# 03/29/2024 13:50:54 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 142.68 examples/s]
# 03/29/2024 13:50:54 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00, 26.15it/s]
# 03/29/2024 13:50:54 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 166.72 examples/s]
# 03/29/2024 13:50:54 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00, 24.73it/s]
# 03/29/2024 13:50:58 - INFO - 	 missing_keys: []
# 03/29/2024 13:50:58 - INFO - 	 unexpected_keys: []
# 03/29/2024 13:50:58 - INFO - 	 mismatched_keys: []
# 03/29/2024 13:50:58 - INFO - 	 error_msgs: []
# 03/29/2024 13:50:58 - INFO - 	 Model Parameters: 90.5M, Transformer: 82.1M, Coref head: 8.4M
# 03/29/2024 13:50:58 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 166.66 examples/s]
# 03/29/2024 13:50:59 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00, 29.65it/s]
# 03/29/2024 13:50:59 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 166.87 examples/s]
# 03/29/2024 13:50:59 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00, 28.26it/s]
# 03/29/2024 13:51:00 - INFO - 	 missing_keys: []
# 03/29/2024 13:51:00 - INFO - 	 unexpected_keys: []
# 03/29/2024 13:51:00 - INFO - 	 mismatched_keys: []
# 03/29/2024 13:51:00 - INFO - 	 error_msgs: []
# 03/29/2024 13:51:00 - INFO - 	 Model Parameters: 90.5M, Transformer: 82.1M, Coref head: 8.4M
# 03/29/2024 13:51:00 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 166.75 examples/s]
# 03/29/2024 13:51:00 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00, 26.63it/s]
# 03/29/2024 13:51:00 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 166.43 examples/s]
# 03/29/2024 13:51:00 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00, 27.39it/s]
# 03/29/2024 13:51:01 - INFO - 	 missing_keys: []
# 03/29/2024 13:51:01 - INFO - 	 unexpected_keys: []
# 03/29/2024 13:51:01 - INFO - 	 mismatched_keys: []
# 03/29/2024 13:51:01 - INFO - 	 error_msgs: []
# 03/29/2024 13:51:01 - INFO - 	 Model Parameters: 90.5M, Transformer: 82.1M, Coref head: 8.4M
# 03/29/2024 13:51:01 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 142.75 examples/s]
# 03/29/2024 13:51:02 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00, 22.52it/s]
# 03/29/2024 13:51:02 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 166.47 examples/s]
# 03/29/2024 13:51:02 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00, 23.10it/s]
# 03/29/2024 13:51:03 - INFO - 	 missing_keys: []
# 03/29/2024 13:51:03 - INFO - 	 unexpected_keys: []
# 03/29/2024 13:51:03 - INFO - 	 mismatched_keys: []
# 03/29/2024 13:51:03 - INFO - 	 error_msgs: []
# 03/29/2024 13:51:03 - INFO - 	 Model Parameters: 90.5M, Transformer: 82.1M, Coref head: 8.4M
# 03/29/2024 13:51:03 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 166.74 examples/s]
# 03/29/2024 13:51:03 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00, 34.08it/s]
# 03/29/2024 13:51:03 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 142.88 examples/s]
# 03/29/2024 13:51:03 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00, 28.63it/s]
# 03/29/2024 13:51:05 - INFO - 	 missing_keys: []
# 03/29/2024 13:51:05 - INFO - 	 unexpected_keys: []
# 03/29/2024 13:51:05 - INFO - 	 mismatched_keys: []
# 03/29/2024 13:51:05 - INFO - 	 error_msgs: []
# 03/29/2024 13:51:05 - INFO - 	 Model Parameters: 90.5M, Transformer: 82.1M, Coref head: 8.4M
# 03/29/2024 13:51:05 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 166.61 examples/s]
# 03/29/2024 13:51:05 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00, 30.90it/s]
# 03/29/2024 13:51:05 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 166.66 examples/s]
# 03/29/2024 13:51:05 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00, 29.59it/s]
# 03/29/2024 13:51:06 - INFO - 	 missing_keys: []
# 03/29/2024 13:51:06 - INFO - 	 unexpected_keys: []
# 03/29/2024 13:51:06 - INFO - 	 mismatched_keys: []
# 03/29/2024 13:51:06 - INFO - 	 error_msgs: []
# 03/29/2024 13:51:06 - INFO - 	 Model Parameters: 90.5M, Transformer: 82.1M, Coref head: 8.4M
# 03/29/2024 13:51:06 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 200.03 examples/s]
# 03/29/2024 13:51:06 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00, 23.43it/s]
# 03/29/2024 13:51:06 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 124.88 examples/s]
# 03/29/2024 13:51:07 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00, 28.46it/s]
# 03/29/2024 13:51:08 - INFO - 	 missing_keys: []
# 03/29/2024 13:51:08 - INFO - 	 unexpected_keys: []
# 03/29/2024 13:51:08 - INFO - 	 mismatched_keys: []
# 03/29/2024 13:51:08 - INFO - 	 error_msgs: []
# 03/29/2024 13:51:08 - INFO - 	 Model Parameters: 90.5M, Transformer: 82.1M, Coref head: 8.4M
# 03/29/2024 13:51:08 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 166.67 examples/s]
# 03/29/2024 13:51:08 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00, 27.07it/s]
# 03/29/2024 13:51:08 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 200.01 examples/s]
# 03/29/2024 13:51:08 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00, 29.60it/s]
# 03/29/2024 13:51:09 - INFO - 	 missing_keys: []
# 03/29/2024 13:51:09 - INFO - 	 unexpected_keys: []
# 03/29/2024 13:51:09 - INFO - 	 mismatched_keys: []
# 03/29/2024 13:51:09 - INFO - 	 error_msgs: []
# 03/29/2024 13:51:09 - INFO - 	 Model Parameters: 90.5M, Transformer: 82.1M, Coref head: 8.4M
# 03/29/2024 13:51:09 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 200.00 examples/s]
# 03/29/2024 13:51:10 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00, 24.09it/s]
# 03/29/2024 13:51:10 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 166.71 examples/s]
# 03/29/2024 13:51:10 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00, 25.30it/s]
# 03/29/2024 13:51:11 - INFO - 	 missing_keys: []
# 03/29/2024 13:51:11 - INFO - 	 unexpected_keys: []
# 03/29/2024 13:51:11 - INFO - 	 mismatched_keys: []
# 03/29/2024 13:51:11 - INFO - 	 error_msgs: []
# 03/29/2024 13:51:11 - INFO - 	 Model Parameters: 90.5M, Transformer: 82.1M, Coref head: 8.4M
# 03/29/2024 13:51:11 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 143.11 examples/s]
# 03/29/2024 13:51:11 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00, 27.35it/s]
# 03/29/2024 13:51:11 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 200.02 examples/s]
# 03/29/2024 13:51:11 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00, 30.33it/s]
# 03/29/2024 13:51:13 - INFO - 	 missing_keys: []
# 03/29/2024 13:51:13 - INFO - 	 unexpected_keys: []
# 03/29/2024 13:51:13 - INFO - 	 mismatched_keys: []
# 03/29/2024 13:51:13 - INFO - 	 error_msgs: []
# 03/29/2024 13:51:13 - INFO - 	 Model Parameters: 90.5M, Transformer: 82.1M, Coref head: 8.4M
# 03/29/2024 13:51:13 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 163.81 examples/s]
# 03/29/2024 13:51:13 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00, 32.27it/s]
# 03/29/2024 13:51:13 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 166.54 examples/s]
# 03/29/2024 13:51:13 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00, 31.24it/s]
# 03/29/2024 13:51:19 - INFO - 	 missing_keys: []
# 03/29/2024 13:51:19 - INFO - 	 unexpected_keys: []
# 03/29/2024 13:51:19 - INFO - 	 mismatched_keys: []
# 03/29/2024 13:51:19 - INFO - 	 error_msgs: []
# 03/29/2024 13:51:19 - INFO - 	 Model Parameters: 90.5M, Transformer: 82.1M, Coref head: 8.4M
# 03/29/2024 13:51:19 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 166.47 examples/s]
# 03/29/2024 13:51:19 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00, 30.88it/s]
# 03/29/2024 13:51:19 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 166.61 examples/s]
# 03/29/2024 13:51:19 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00, 30.13it/s]
# 03/29/2024 13:51:20 - INFO - 	 missing_keys: []
# 03/29/2024 13:51:20 - INFO - 	 unexpected_keys: []
# 03/29/2024 13:51:20 - INFO - 	 mismatched_keys: []
# 03/29/2024 13:51:20 - INFO - 	 error_msgs: []
# 03/29/2024 13:51:20 - INFO - 	 Model Parameters: 90.5M, Transformer: 82.1M, Coref head: 8.4M
# 03/29/2024 13:51:20 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 166.67 examples/s]
# 03/29/2024 13:51:20 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00, 27.78it/s]
# 03/29/2024 13:51:20 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 166.70 examples/s]
# 03/29/2024 13:51:20 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00, 27.03it/s]
# 03/29/2024 13:51:22 - INFO - 	 missing_keys: []
# 03/29/2024 13:51:22 - INFO - 	 unexpected_keys: []
# 03/29/2024 13:51:22 - INFO - 	 mismatched_keys: []
# 03/29/2024 13:51:22 - INFO - 	 error_msgs: []
# 03/29/2024 13:51:22 - INFO - 	 Model Parameters: 90.5M, Transformer: 82.1M, Coref head: 8.4M
# 03/29/2024 13:51:22 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 141.02 examples/s]
# 03/29/2024 13:51:22 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00, 25.94it/s]
# 03/29/2024 13:51:22 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 166.46 examples/s]
# 03/29/2024 13:51:22 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00, 28.57it/s]
# 03/29/2024 13:51:23 - INFO - 	 missing_keys: []
# 03/29/2024 13:51:23 - INFO - 	 unexpected_keys: []
# 03/29/2024 13:51:23 - INFO - 	 mismatched_keys: []
# 03/29/2024 13:51:23 - INFO - 	 error_msgs: []
# 03/29/2024 13:51:23 - INFO - 	 Model Parameters: 90.5M, Transformer: 82.1M, Coref head: 8.4M
# 03/29/2024 13:51:23 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 200.05 examples/s]
# 03/29/2024 13:51:23 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00, 24.89it/s]
# 03/29/2024 13:51:23 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 166.53 examples/s]
# 03/29/2024 13:51:24 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00, 26.18it/s]
# 03/29/2024 13:51:25 - INFO - 	 missing_keys: []
# 03/29/2024 13:51:25 - INFO - 	 unexpected_keys: []
# 03/29/2024 13:51:25 - INFO - 	 mismatched_keys: []
# 03/29/2024 13:51:25 - INFO - 	 error_msgs: []
# 03/29/2024 13:51:25 - INFO - 	 Model Parameters: 90.5M, Transformer: 82.1M, Coref head: 8.4M
# 03/29/2024 13:51:25 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 90.88 examples/s]
# 03/29/2024 13:51:25 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00, 16.02it/s]
# 03/29/2024 13:51:25 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 124.88 examples/s]
# 03/29/2024 13:51:25 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00, 17.04it/s]
# 03/29/2024 13:51:26 - INFO - 	 missing_keys: []
# 03/29/2024 13:51:26 - INFO - 	 unexpected_keys: []
# 03/29/2024 13:51:26 - INFO - 	 mismatched_keys: []
# 03/29/2024 13:51:26 - INFO - 	 error_msgs: []
# 03/29/2024 13:51:26 - INFO - 	 Model Parameters: 90.5M, Transformer: 82.1M, Coref head: 8.4M
# 03/29/2024 13:51:26 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 90.90 examples/s]
# 03/29/2024 13:51:26 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00, 14.93it/s]
# 03/29/2024 13:51:27 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 76.92 examples/s]
# 03/29/2024 13:51:27 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00, 14.41it/s]
# 03/29/2024 13:51:28 - INFO - 	 missing_keys: []
# 03/29/2024 13:51:28 - INFO - 	 unexpected_keys: []
# 03/29/2024 13:51:28 - INFO - 	 mismatched_keys: []
# 03/29/2024 13:51:28 - INFO - 	 error_msgs: []
# 03/29/2024 13:51:28 - INFO - 	 Model Parameters: 90.5M, Transformer: 82.1M, Coref head: 8.4M
# 03/29/2024 13:51:28 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 124.98 examples/s]
# 03/29/2024 13:51:28 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00, 17.39it/s]
# 03/29/2024 13:51:28 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 143.55 examples/s]
# 03/29/2024 13:51:28 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00, 17.18it/s]
# 03/29/2024 13:51:29 - INFO - 	 missing_keys: []
# 03/29/2024 13:51:29 - INFO - 	 unexpected_keys: []
# 03/29/2024 13:51:29 - INFO - 	 mismatched_keys: []
# 03/29/2024 13:51:29 - INFO - 	 error_msgs: []
# 03/29/2024 13:51:29 - INFO - 	 Model Parameters: 90.5M, Transformer: 82.1M, Coref head: 8.4M
# 03/29/2024 13:51:29 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 166.67 examples/s]
# 03/29/2024 13:51:30 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00, 25.64it/s]
# 03/29/2024 13:51:30 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 166.67 examples/s]
# 03/29/2024 13:51:30 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00, 32.25it/s]
# 03/29/2024 13:51:31 - INFO - 	 missing_keys: []
# 03/29/2024 13:51:31 - INFO - 	 unexpected_keys: []
# 03/29/2024 13:51:31 - INFO - 	 mismatched_keys: []
# 03/29/2024 13:51:31 - INFO - 	 error_msgs: []
# 03/29/2024 13:51:31 - INFO - 	 Model Parameters: 90.5M, Transformer: 82.1M, Coref head: 8.4M
# 03/29/2024 13:51:31 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 166.70 examples/s]
# 03/29/2024 13:51:31 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00, 27.56it/s]
# 03/29/2024 13:51:31 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 142.67 examples/s]
# 03/29/2024 13:51:31 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00, 27.99it/s]
# 03/29/2024 13:51:33 - INFO - 	 missing_keys: []
# 03/29/2024 13:51:33 - INFO - 	 unexpected_keys: []
# 03/29/2024 13:51:33 - INFO - 	 mismatched_keys: []
# 03/29/2024 13:51:33 - INFO - 	 error_msgs: []
# 03/29/2024 13:51:33 - INFO - 	 Model Parameters: 90.5M, Transformer: 82.1M, Coref head: 8.4M
# 03/29/2024 13:51:33 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 99.91 examples/s]
# 03/29/2024 13:51:33 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00, 14.82it/s]
# 03/29/2024 13:51:33 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 99.92 examples/s]
# 03/29/2024 13:51:33 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00, 14.92it/s]
# 03/29/2024 13:51:38 - INFO - 	 missing_keys: []
# 03/29/2024 13:51:38 - INFO - 	 unexpected_keys: []
# 03/29/2024 13:51:38 - INFO - 	 mismatched_keys: []
# 03/29/2024 13:51:38 - INFO - 	 error_msgs: []
# 03/29/2024 13:51:38 - INFO - 	 Model Parameters: 90.5M, Transformer: 82.1M, Coref head: 8.4M
# 03/29/2024 13:51:38 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 142.84 examples/s]
# 03/29/2024 13:51:38 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00, 19.11it/s]
# 03/29/2024 13:51:38 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 142.70 examples/s]
# 03/29/2024 13:51:38 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00, 18.09it/s]
# 03/29/2024 13:51:39 - INFO - 	 missing_keys: []
# 03/29/2024 13:51:39 - INFO - 	 unexpected_keys: []
# 03/29/2024 13:51:39 - INFO - 	 mismatched_keys: []
# 03/29/2024 13:51:39 - INFO - 	 error_msgs: []
# 03/29/2024 13:51:39 - INFO - 	 Model Parameters: 90.5M, Transformer: 82.1M, Coref head: 8.4M
# 03/29/2024 13:51:39 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 200.02 examples/s]
# 03/29/2024 13:51:39 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00, 27.06it/s]
# 03/29/2024 13:51:39 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 166.66 examples/s]
# 03/29/2024 13:51:39 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00, 26.38it/s]
# 03/29/2024 13:51:41 - INFO - 	 missing_keys: []
# 03/29/2024 13:51:41 - INFO - 	 unexpected_keys: []
# 03/29/2024 13:51:41 - INFO - 	 mismatched_keys: []
# 03/29/2024 13:51:41 - INFO - 	 error_msgs: []
# 03/29/2024 13:51:41 - INFO - 	 Model Parameters: 90.5M, Transformer: 82.1M, Coref head: 8.4M
# 03/29/2024 13:51:41 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 99.79 examples/s]
# 03/29/2024 13:51:41 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00, 26.29it/s]
# 03/29/2024 13:51:41 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 166.66 examples/s]
# 03/29/2024 13:51:41 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00, 25.45it/s]
# 03/29/2024 13:51:42 - INFO - 	 missing_keys: []
# 03/29/2024 13:51:42 - INFO - 	 unexpected_keys: []
# 03/29/2024 13:51:42 - INFO - 	 mismatched_keys: []
# 03/29/2024 13:51:42 - INFO - 	 error_msgs: []
# 03/29/2024 13:51:42 - INFO - 	 Model Parameters: 90.5M, Transformer: 82.1M, Coref head: 8.4M
# 03/29/2024 13:51:42 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 199.66 examples/s]
# 03/29/2024 13:51:42 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00, 28.71it/s]
# 03/29/2024 13:51:42 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 136.99 examples/s]
# 03/29/2024 13:51:43 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00, 26.80it/s]
# 03/29/2024 13:51:44 - INFO - 	 missing_keys: []
# 03/29/2024 13:51:44 - INFO - 	 unexpected_keys: []
# 03/29/2024 13:51:44 - INFO - 	 mismatched_keys: []
# 03/29/2024 13:51:44 - INFO - 	 error_msgs: []
# 03/29/2024 13:51:44 - INFO - 	 Model Parameters: 90.5M, Transformer: 82.1M, Coref head: 8.4M
# 03/29/2024 13:51:44 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 166.88 examples/s]
# 03/29/2024 13:51:44 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00, 25.66it/s]
# 03/29/2024 13:51:44 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 166.68 examples/s]
# 03/29/2024 13:51:44 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00, 26.80it/s]
# 03/29/2024 13:51:45 - INFO - 	 missing_keys: []
# 03/29/2024 13:51:45 - INFO - 	 unexpected_keys: []
# 03/29/2024 13:51:45 - INFO - 	 mismatched_keys: []
# 03/29/2024 13:51:45 - INFO - 	 error_msgs: []
# 03/29/2024 13:51:45 - INFO - 	 Model Parameters: 90.5M, Transformer: 82.1M, Coref head: 8.4M
# 03/29/2024 13:51:45 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 142.61 examples/s]
# 03/29/2024 13:51:45 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00, 21.69it/s]
# 03/29/2024 13:51:46 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 146.45 examples/s]
# 03/29/2024 13:51:46 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00, 19.88it/s]
# 03/29/2024 13:51:47 - INFO - 	 missing_keys: []
# 03/29/2024 13:51:47 - INFO - 	 unexpected_keys: []
# 03/29/2024 13:51:47 - INFO - 	 mismatched_keys: []
# 03/29/2024 13:51:47 - INFO - 	 error_msgs: []
# 03/29/2024 13:51:47 - INFO - 	 Model Parameters: 90.5M, Transformer: 82.1M, Coref head: 8.4M
# 03/29/2024 13:51:47 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 125.01 examples/s]
# 03/29/2024 13:51:47 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00, 17.89it/s]
# 03/29/2024 13:51:47 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 124.99 examples/s]
# 03/29/2024 13:51:48 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00, 20.22it/s]
# 03/29/2024 13:51:49 - INFO - 	 missing_keys: []
# 03/29/2024 13:51:49 - INFO - 	 unexpected_keys: []
# 03/29/2024 13:51:49 - INFO - 	 mismatched_keys: []
# 03/29/2024 13:51:49 - INFO - 	 error_msgs: []
# 03/29/2024 13:51:49 - INFO - 	 Model Parameters: 90.5M, Transformer: 82.1M, Coref head: 8.4M
# 03/29/2024 13:51:49 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 166.65 examples/s]
# 03/29/2024 13:51:49 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00, 30.31it/s]
# 03/29/2024 13:51:49 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 166.65 examples/s]
# 03/29/2024 13:51:49 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00, 28.10it/s]
# 03/29/2024 13:51:50 - INFO - 	 missing_keys: []
# 03/29/2024 13:51:50 - INFO - 	 unexpected_keys: []
# 03/29/2024 13:51:50 - INFO - 	 mismatched_keys: []
# 03/29/2024 13:51:50 - INFO - 	 error_msgs: []
# 03/29/2024 13:51:50 - INFO - 	 Model Parameters: 90.5M, Transformer: 82.1M, Coref head: 8.4M
# 03/29/2024 13:51:50 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 166.44 examples/s]
# 03/29/2024 13:51:51 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00, 23.75it/s]
# 03/29/2024 13:51:51 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 166.71 examples/s]
# 03/29/2024 13:51:51 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00, 23.26it/s]
# 03/29/2024 13:51:52 - INFO - 	 missing_keys: []
# 03/29/2024 13:51:52 - INFO - 	 unexpected_keys: []
# 03/29/2024 13:51:52 - INFO - 	 mismatched_keys: []
# 03/29/2024 13:51:52 - INFO - 	 error_msgs: []
# 03/29/2024 13:51:52 - INFO - 	 Model Parameters: 90.5M, Transformer: 82.1M, Coref head: 8.4M
# 03/29/2024 13:51:52 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 165.80 examples/s]
# 03/29/2024 13:51:52 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00, 27.16it/s]
# 03/29/2024 13:51:52 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 166.59 examples/s]
# 03/29/2024 13:51:52 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00, 30.34it/s]
# 03/29/2024 13:51:57 - INFO - 	 missing_keys: []
# 03/29/2024 13:51:57 - INFO - 	 unexpected_keys: []
# 03/29/2024 13:51:57 - INFO - 	 mismatched_keys: []
# 03/29/2024 13:51:57 - INFO - 	 error_msgs: []
# 03/29/2024 13:51:57 - INFO - 	 Model Parameters: 90.5M, Transformer: 82.1M, Coref head: 8.4M
# 03/29/2024 13:51:57 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 142.87 examples/s]
# 03/29/2024 13:51:57 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00, 22.73it/s]
# 03/29/2024 13:51:57 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 155.15 examples/s]
# 03/29/2024 13:51:57 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00, 22.13it/s]
# 03/29/2024 13:51:58 - INFO - 	 missing_keys: []
# 03/29/2024 13:51:58 - INFO - 	 unexpected_keys: []
# 03/29/2024 13:51:58 - INFO - 	 mismatched_keys: []
# 03/29/2024 13:51:58 - INFO - 	 error_msgs: []
# 03/29/2024 13:51:58 - INFO - 	 Model Parameters: 90.5M, Transformer: 82.1M, Coref head: 8.4M
# 03/29/2024 13:51:58 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 99.97 examples/s]
# 03/29/2024 13:51:58 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00, 21.11it/s]
# 03/29/2024 13:51:59 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 142.86 examples/s]
# 03/29/2024 13:51:59 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00, 21.26it/s]
# 03/29/2024 13:52:00 - INFO - 	 missing_keys: []
# 03/29/2024 13:52:00 - INFO - 	 unexpected_keys: []
# 03/29/2024 13:52:00 - INFO - 	 mismatched_keys: []
# 03/29/2024 13:52:00 - INFO - 	 error_msgs: []
# 03/29/2024 13:52:00 - INFO - 	 Model Parameters: 90.5M, Transformer: 82.1M, Coref head: 8.4M
# 03/29/2024 13:52:00 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 200.00 examples/s]
# 03/29/2024 13:52:00 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00, 26.74it/s]
# 03/29/2024 13:52:00 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 199.95 examples/s]
# 03/29/2024 13:52:00 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00, 30.15it/s]
# 03/29/2024 13:52:02 - INFO - 	 missing_keys: []
# 03/29/2024 13:52:02 - INFO - 	 unexpected_keys: []
# 03/29/2024 13:52:02 - INFO - 	 mismatched_keys: []
# 03/29/2024 13:52:02 - INFO - 	 error_msgs: []
# 03/29/2024 13:52:02 - INFO - 	 Model Parameters: 90.5M, Transformer: 82.1M, Coref head: 8.4M
# 03/29/2024 13:52:02 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 166.67 examples/s]
# 03/29/2024 13:52:02 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00, 23.81it/s]
# 03/29/2024 13:52:02 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 166.45 examples/s]
# 03/29/2024 13:52:02 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00, 23.23it/s]
# 03/29/2024 13:52:04 - INFO - 	 missing_keys: []
# 03/29/2024 13:52:04 - INFO - 	 unexpected_keys: []
# 03/29/2024 13:52:04 - INFO - 	 mismatched_keys: []
# 03/29/2024 13:52:04 - INFO - 	 error_msgs: []
# 03/29/2024 13:52:04 - INFO - 	 Model Parameters: 90.5M, Transformer: 82.1M, Coref head: 8.4M
# 03/29/2024 13:52:04 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 163.82 examples/s]
# 03/29/2024 13:52:04 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00, 28.02it/s]
# 03/29/2024 13:52:04 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 166.55 examples/s]
# 03/29/2024 13:52:04 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00, 27.70it/s]
# 03/29/2024 13:52:05 - INFO - 	 missing_keys: []
# 03/29/2024 13:52:05 - INFO - 	 unexpected_keys: []
# 03/29/2024 13:52:05 - INFO - 	 mismatched_keys: []
# 03/29/2024 13:52:05 - INFO - 	 error_msgs: []
# 03/29/2024 13:52:05 - INFO - 	 Model Parameters: 90.5M, Transformer: 82.1M, Coref head: 8.4M
# 03/29/2024 13:52:05 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 166.28 examples/s]
# 03/29/2024 13:52:05 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00, 30.55it/s]
# 03/29/2024 13:52:05 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 200.01 examples/s]
# 03/29/2024 13:52:05 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00, 27.92it/s]
# 03/29/2024 13:52:07 - INFO - 	 missing_keys: []
# 03/29/2024 13:52:07 - INFO - 	 unexpected_keys: []
# 03/29/2024 13:52:07 - INFO - 	 mismatched_keys: []
# 03/29/2024 13:52:07 - INFO - 	 error_msgs: []
# 03/29/2024 13:52:07 - INFO - 	 Model Parameters: 90.5M, Transformer: 82.1M, Coref head: 8.4M
# 03/29/2024 13:52:07 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 166.65 examples/s]
# 03/29/2024 13:52:07 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00, 31.76it/s]
# 03/29/2024 13:52:07 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 142.86 examples/s]
# 03/29/2024 13:52:07 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00, 28.37it/s]
# 03/29/2024 13:52:08 - INFO - 	 missing_keys: []
# 03/29/2024 13:52:08 - INFO - 	 unexpected_keys: []
# 03/29/2024 13:52:08 - INFO - 	 mismatched_keys: []
# 03/29/2024 13:52:08 - INFO - 	 error_msgs: []
# 03/29/2024 13:52:08 - INFO - 	 Model Parameters: 90.5M, Transformer: 82.1M, Coref head: 8.4M
# 03/29/2024 13:52:08 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 123.58 examples/s]
# 03/29/2024 13:52:08 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00, 23.71it/s]
# 03/29/2024 13:52:08 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 142.91 examples/s]
# 03/29/2024 13:52:08 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00, 25.67it/s]
# 03/29/2024 13:52:10 - INFO - 	 missing_keys: []
# 03/29/2024 13:52:10 - INFO - 	 unexpected_keys: []
# 03/29/2024 13:52:10 - INFO - 	 mismatched_keys: []
# 03/29/2024 13:52:10 - INFO - 	 error_msgs: []
# 03/29/2024 13:52:10 - INFO - 	 Model Parameters: 90.5M, Transformer: 82.1M, Coref head: 8.4M
# 03/29/2024 13:52:10 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 111.10 examples/s]
# 03/29/2024 13:52:10 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00, 25.13it/s]
# 03/29/2024 13:52:10 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 125.02 examples/s]
# 03/29/2024 13:52:10 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00, 25.15it/s]
# 03/29/2024 13:52:11 - INFO - 	 missing_keys: []
# 03/29/2024 13:52:11 - INFO - 	 unexpected_keys: []
# 03/29/2024 13:52:11 - INFO - 	 mismatched_keys: []
# 03/29/2024 13:52:11 - INFO - 	 error_msgs: []
# 03/29/2024 13:52:11 - INFO - 	 Model Parameters: 90.5M, Transformer: 82.1M, Coref head: 8.4M
# 03/29/2024 13:52:11 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 166.46 examples/s]
# 03/29/2024 13:52:11 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00, 25.38it/s]
# 03/29/2024 13:52:11 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 142.83 examples/s]
# 03/29/2024 13:52:11 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00, 26.30it/s]
# 03/29/2024 13:52:16 - INFO - 	 missing_keys: []
# 03/29/2024 13:52:16 - INFO - 	 unexpected_keys: []
# 03/29/2024 13:52:16 - INFO - 	 mismatched_keys: []
# 03/29/2024 13:52:16 - INFO - 	 error_msgs: []
# 03/29/2024 13:52:16 - INFO - 	 Model Parameters: 90.5M, Transformer: 82.1M, Coref head: 8.4M
# 03/29/2024 13:52:16 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 166.45 examples/s]
# 03/29/2024 13:52:16 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00, 23.78it/s]
# 03/29/2024 13:52:16 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 142.83 examples/s]
# 03/29/2024 13:52:16 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00, 24.24it/s]
# 03/29/2024 13:52:18 - INFO - 	 missing_keys: []
# 03/29/2024 13:52:18 - INFO - 	 unexpected_keys: []
# 03/29/2024 13:52:18 - INFO - 	 mismatched_keys: []
# 03/29/2024 13:52:18 - INFO - 	 error_msgs: []
# 03/29/2024 13:52:18 - INFO - 	 Model Parameters: 90.5M, Transformer: 82.1M, Coref head: 8.4M
# 03/29/2024 13:52:18 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 142.81 examples/s]
# 03/29/2024 13:52:18 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00, 23.98it/s]
# 03/29/2024 13:52:18 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 166.45 examples/s]
# 03/29/2024 13:52:18 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00, 20.85it/s]
# 03/29/2024 13:52:19 - INFO - 	 missing_keys: []
# 03/29/2024 13:52:19 - INFO - 	 unexpected_keys: []
# 03/29/2024 13:52:19 - INFO - 	 mismatched_keys: []
# 03/29/2024 13:52:19 - INFO - 	 error_msgs: []
# 03/29/2024 13:52:20 - INFO - 	 Model Parameters: 90.5M, Transformer: 82.1M, Coref head: 8.4M
# ...
# Map: 100%|██████████| 1/1 [00:00<00:00, 125.12 examples/s]
# 03/29/2024 13:56:05 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00, 18.32it/s]
# 03/29/2024 13:56:05 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 111.22 examples/s]
# 03/29/2024 13:56:05 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00, 18.52it/s]
# 03/29/2024 13:56:11 - INFO - 	 missing_keys: []
# 03/29/2024 13:56:11 - INFO - 	 unexpected_keys: []
# 03/29/2024 13:56:11 - INFO - 	 mismatched_keys: []
# 03/29/2024 13:56:11 - INFO - 	 error_msgs: []
# 03/29/2024 13:56:11 - INFO - 	 Model Parameters: 90.5M, Transformer: 82.1M, Coref head: 8.4M
# 03/29/2024 13:56:11 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 166.80 examples/s]
# 03/29/2024 13:56:11 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00, 27.03it/s]
# 03/29/2024 13:56:11 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 166.68 examples/s]
# 03/29/2024 13:56:11 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00, 30.30it/s]
# 03/29/2024 13:56:12 - INFO - 	 missing_keys: []
# 03/29/2024 13:56:12 - INFO - 	 unexpected_keys: []
# 03/29/2024 13:56:12 - INFO - 	 mismatched_keys: []
# 03/29/2024 13:56:12 - INFO - 	 error_msgs: []
# 03/29/2024 13:56:12 - INFO - 	 Model Parameters: 90.5M, Transformer: 82.1M, Coref head: 8.4M
# 03/29/2024 13:56:12 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 90.84 examples/s]
# 03/29/2024 13:56:12 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00, 27.98it/s]
# 03/29/2024 13:56:13 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 196.74 examples/s]
# 03/29/2024 13:56:13 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00, 26.59it/s]
# 03/29/2024 13:56:14 - INFO - 	 missing_keys: []
# 03/29/2024 13:56:14 - INFO - 	 unexpected_keys: []
# 03/29/2024 13:56:14 - INFO - 	 mismatched_keys: []
# 03/29/2024 13:56:14 - INFO - 	 error_msgs: []
# 03/29/2024 13:56:14 - INFO - 	 Model Parameters: 90.5M, Transformer: 82.1M, Coref head: 8.4M
# 03/29/2024 13:56:14 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 166.66 examples/s]
# 03/29/2024 13:56:14 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00, 24.86it/s]
# 03/29/2024 13:56:14 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 199.66 examples/s]
# 03/29/2024 13:56:14 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00, 26.36it/s]
# 03/29/2024 13:56:15 - INFO - 	 missing_keys: []
# 03/29/2024 13:56:15 - INFO - 	 unexpected_keys: []
# 03/29/2024 13:56:15 - INFO - 	 mismatched_keys: []
# 03/29/2024 13:56:15 - INFO - 	 error_msgs: []
# 03/29/2024 13:56:15 - INFO - 	 Model Parameters: 90.5M, Transformer: 82.1M, Coref head: 8.4M
# 03/29/2024 13:56:15 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 166.07 examples/s]
# 03/29/2024 13:56:16 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00, 33.11it/s]
# 03/29/2024 13:56:16 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 200.01 examples/s]
# 03/29/2024 13:56:16 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00, 30.21it/s]
# 03/29/2024 13:56:17 - INFO - 	 missing_keys: []
# 03/29/2024 13:56:17 - INFO - 	 unexpected_keys: []
# 03/29/2024 13:56:17 - INFO - 	 mismatched_keys: []
# 03/29/2024 13:56:17 - INFO - 	 error_msgs: []
# 03/29/2024 13:56:17 - INFO - 	 Model Parameters: 90.5M, Transformer: 82.1M, Coref head: 8.4M
# 03/29/2024 13:56:17 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 169.65 examples/s]
# 03/29/2024 13:56:17 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00, 29.99it/s]
# 03/29/2024 13:56:17 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 199.99 examples/s]
# 03/29/2024 13:56:17 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00, 31.40it/s]
# 03/29/2024 13:56:18 - INFO - 	 missing_keys: []
# 03/29/2024 13:56:18 - INFO - 	 unexpected_keys: []
# 03/29/2024 13:56:18 - INFO - 	 mismatched_keys: []
# 03/29/2024 13:56:18 - INFO - 	 error_msgs: []
# 03/29/2024 13:56:18 - INFO - 	 Model Parameters: 90.5M, Transformer: 82.1M, Coref head: 8.4M
# 03/29/2024 13:56:18 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 166.37 examples/s]
# 03/29/2024 13:56:19 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00, 25.00it/s]
# 03/29/2024 13:56:19 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 166.45 examples/s]
# 03/29/2024 13:56:19 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00, 27.17it/s]
# 03/29/2024 13:56:20 - INFO - 	 missing_keys: []
# 03/29/2024 13:56:20 - INFO - 	 unexpected_keys: []
# 03/29/2024 13:56:20 - INFO - 	 mismatched_keys: []
# 03/29/2024 13:56:20 - INFO - 	 error_msgs: []
# 03/29/2024 13:56:20 - INFO - 	 Model Parameters: 90.5M, Transformer: 82.1M, Coref head: 8.4M
# 03/29/2024 13:56:20 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 150.93 examples/s]
# 03/29/2024 13:56:20 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00, 23.82it/s]
# 03/29/2024 13:56:20 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 165.93 examples/s]
# 03/29/2024 13:56:20 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00, 26.91it/s]
# 03/29/2024 13:56:21 - INFO - 	 missing_keys: []
# 03/29/2024 13:56:21 - INFO - 	 unexpected_keys: []
# 03/29/2024 13:56:21 - INFO - 	 mismatched_keys: []
# 03/29/2024 13:56:21 - INFO - 	 error_msgs: []
# 03/29/2024 13:56:21 - INFO - 	 Model Parameters: 90.5M, Transformer: 82.1M, Coref head: 8.4M
# 03/29/2024 13:56:21 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 142.70 examples/s]
# 03/29/2024 13:56:22 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00, 22.05it/s]
# 03/29/2024 13:56:22 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 166.69 examples/s]
# 03/29/2024 13:56:22 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00, 21.95it/s]
# 03/29/2024 13:56:23 - INFO - 	 missing_keys: []
# 03/29/2024 13:56:23 - INFO - 	 unexpected_keys: []
# 03/29/2024 13:56:23 - INFO - 	 mismatched_keys: []
# 03/29/2024 13:56:23 - INFO - 	 error_msgs: []
# 03/29/2024 13:56:23 - INFO - 	 Model Parameters: 90.5M, Transformer: 82.1M, Coref head: 8.4M
# 03/29/2024 13:56:23 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 142.89 examples/s]
# 03/29/2024 13:56:23 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00, 23.26it/s]
# 03/29/2024 13:56:23 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 124.99 examples/s]
# 03/29/2024 13:56:23 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00, 24.08it/s]
# 03/29/2024 13:56:25 - INFO - 	 missing_keys: []
# 03/29/2024 13:56:25 - INFO - 	 unexpected_keys: []
# 03/29/2024 13:56:25 - INFO - 	 mismatched_keys: []
# 03/29/2024 13:56:25 - INFO - 	 error_msgs: []
# 03/29/2024 13:56:25 - INFO - 	 Model Parameters: 90.5M, Transformer: 82.1M, Coref head: 8.4M
# 03/29/2024 13:56:25 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 166.66 examples/s]
# 03/29/2024 13:56:25 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00, 33.33it/s]
# 03/29/2024 13:56:25 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 199.73 examples/s]
# 03/29/2024 13:56:25 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00, 29.39it/s]
# 03/29/2024 13:56:30 - INFO - 	 missing_keys: []
# 03/29/2024 13:56:30 - INFO - 	 unexpected_keys: []
# 03/29/2024 13:56:30 - INFO - 	 mismatched_keys: []
# 03/29/2024 13:56:30 - INFO - 	 error_msgs: []
# 03/29/2024 13:56:30 - INFO - 	 Model Parameters: 90.5M, Transformer: 82.1M, Coref head: 8.4M
# 03/29/2024 13:56:30 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 166.49 examples/s]
# 03/29/2024 13:56:30 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00, 20.38it/s]
# 03/29/2024 13:56:30 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 142.40 examples/s]
# 03/29/2024 13:56:30 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00, 23.26it/s]
# 03/29/2024 13:56:32 - INFO - 	 missing_keys: []
# 03/29/2024 13:56:32 - INFO - 	 unexpected_keys: []
# 03/29/2024 13:56:32 - INFO - 	 mismatched_keys: []
# 03/29/2024 13:56:32 - INFO - 	 error_msgs: []
# 03/29/2024 13:56:32 - INFO - 	 Model Parameters: 90.5M, Transformer: 82.1M, Coref head: 8.4M
# 03/29/2024 13:56:32 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 166.61 examples/s]
# 03/29/2024 13:56:32 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00, 29.61it/s]
# 03/29/2024 13:56:32 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 199.83 examples/s]
# 03/29/2024 13:56:32 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00, 30.79it/s]
# 03/29/2024 13:56:33 - INFO - 	 missing_keys: []
# 03/29/2024 13:56:33 - INFO - 	 unexpected_keys: []
# 03/29/2024 13:56:33 - INFO - 	 mismatched_keys: []
# 03/29/2024 13:56:33 - INFO - 	 error_msgs: []
# 03/29/2024 13:56:33 - INFO - 	 Model Parameters: 90.5M, Transformer: 82.1M, Coref head: 8.4M
# 03/29/2024 13:56:33 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 166.59 examples/s]
# 03/29/2024 13:56:33 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00, 24.89it/s]
# 03/29/2024 13:56:33 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 166.10 examples/s]
# 03/29/2024 13:56:33 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00, 24.86it/s]
# 03/29/2024 13:56:35 - INFO - 	 missing_keys: []
# 03/29/2024 13:56:35 - INFO - 	 unexpected_keys: []
# 03/29/2024 13:56:35 - INFO - 	 mismatched_keys: []
# 03/29/2024 13:56:35 - INFO - 	 error_msgs: []
# 03/29/2024 13:56:35 - INFO - 	 Model Parameters: 90.5M, Transformer: 82.1M, Coref head: 8.4M
# 03/29/2024 13:56:35 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 142.79 examples/s]
# 03/29/2024 13:56:35 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00, 25.23it/s]
# 03/29/2024 13:56:35 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 166.70 examples/s]
# 03/29/2024 13:56:35 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00, 27.50it/s]
# 03/29/2024 13:56:36 - INFO - 	 missing_keys: []
# 03/29/2024 13:56:36 - INFO - 	 unexpected_keys: []
# 03/29/2024 13:56:36 - INFO - 	 mismatched_keys: []
# 03/29/2024 13:56:36 - INFO - 	 error_msgs: []
# 03/29/2024 13:56:36 - INFO - 	 Model Parameters: 90.5M, Transformer: 82.1M, Coref head: 8.4M
# 03/29/2024 13:56:36 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 111.20 examples/s]
# 03/29/2024 13:56:36 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00, 26.72it/s]
# 03/29/2024 13:56:36 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 142.86 examples/s]
# 03/29/2024 13:56:36 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00, 24.11it/s]
# 03/29/2024 13:56:38 - INFO - 	 missing_keys: []
# 03/29/2024 13:56:38 - INFO - 	 unexpected_keys: []
# 03/29/2024 13:56:38 - INFO - 	 mismatched_keys: []
# 03/29/2024 13:56:38 - INFO - 	 error_msgs: []
# 03/29/2024 13:56:38 - INFO - 	 Model Parameters: 90.5M, Transformer: 82.1M, Coref head: 8.4M
# 03/29/2024 13:56:38 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 143.02 examples/s]
# 03/29/2024 13:56:38 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00, 22.28it/s]
# 03/29/2024 13:56:38 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 142.62 examples/s]
# 03/29/2024 13:56:38 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00, 22.43it/s]
# 03/29/2024 13:56:40 - INFO - 	 missing_keys: []
# 03/29/2024 13:56:40 - INFO - 	 unexpected_keys: []
# 03/29/2024 13:56:40 - INFO - 	 mismatched_keys: []
# 03/29/2024 13:56:40 - INFO - 	 error_msgs: []
# 03/29/2024 13:56:40 - INFO - 	 Model Parameters: 90.5M, Transformer: 82.1M, Coref head: 8.4M
# 03/29/2024 13:56:40 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 142.93 examples/s]
# 03/29/2024 13:56:40 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00, 26.76it/s]
# 03/29/2024 13:56:40 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 142.84 examples/s]
# 03/29/2024 13:56:40 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00, 26.32it/s]
# 03/29/2024 13:56:41 - INFO - 	 missing_keys: []
# 03/29/2024 13:56:41 - INFO - 	 unexpected_keys: []
# 03/29/2024 13:56:41 - INFO - 	 mismatched_keys: []
# 03/29/2024 13:56:41 - INFO - 	 error_msgs: []
# 03/29/2024 13:56:41 - INFO - 	 Model Parameters: 90.5M, Transformer: 82.1M, Coref head: 8.4M
# 03/29/2024 13:56:41 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 166.34 examples/s]
# 03/29/2024 13:56:41 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00, 28.77it/s]
# 03/29/2024 13:56:41 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 200.00 examples/s]
# 03/29/2024 13:56:41 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00, 28.79it/s]
# 03/29/2024 13:56:43 - INFO - 	 missing_keys: []
# 03/29/2024 13:56:43 - INFO - 	 unexpected_keys: []
# 03/29/2024 13:56:43 - INFO - 	 mismatched_keys: []
# 03/29/2024 13:56:43 - INFO - 	 error_msgs: []
# 03/29/2024 13:56:43 - INFO - 	 Model Parameters: 90.5M, Transformer: 82.1M, Coref head: 8.4M
# 03/29/2024 13:56:43 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 200.30 examples/s]
# 03/29/2024 13:56:43 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00, 31.41it/s]
# 03/29/2024 13:56:43 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 199.98 examples/s]
# 03/29/2024 13:56:43 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00, 34.87it/s]
# 03/29/2024 13:56:44 - INFO - 	 missing_keys: []
# 03/29/2024 13:56:44 - INFO - 	 unexpected_keys: []
# 03/29/2024 13:56:44 - INFO - 	 mismatched_keys: []
# 03/29/2024 13:56:44 - INFO - 	 error_msgs: []
# 03/29/2024 13:56:44 - INFO - 	 Model Parameters: 90.5M, Transformer: 82.1M, Coref head: 8.4M
# 03/29/2024 13:56:44 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 200.16 examples/s]
# 03/29/2024 13:56:44 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00, 32.53it/s]
# 03/29/2024 13:56:44 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 199.82 examples/s]
# 03/29/2024 13:56:44 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00, 35.10it/s]
# {'Rule-based': {'Exact Match': 0.15,
#   'F1': 0.15,
#   'Avg Time (s)': 1.5228856801986694},
#  'BERT': {'Exact Match': 0.25,
#   'F1': 0.2977777777777778,
#   'Avg Time (s)': 1.981279981136322}}

# %% [markdown]
# |                | Exact Match | F1                | Avg Time (s)      |
# |----------------|-------------|-------------------|-------------------|
# | Rule-based     | 0.15        | 0.15              | 1.5228856801986694|
# | BERT           | 0.25        | 0.2977777777777778| 1.981279981136322 |

# %% [markdown]
# ## B. References
#
# Ke, Y.H., Jin, L., Elangovan, K., Abdullah, H.R., Liu, N., Sia, A.T.H., Soh, C.R., Tung, J.Y.M., Ong, J.C.L. & Ting, D.S.W. 2024, 'Development and Testing of Retrieval Augmented Generation in Large Language Models -- A Case Study Report', ArXiv, pp. 1-22
#
# The Stanford Natural Language Processing Group. 2024, Dev Set v2.0, SQuAD2.0 The Stanford Question Answering Dataset, viewed 29 March 2024, <https://rajpurkar.github.io/SQuAD-explorer/>.
#
# The Stanford Natural Language Processing Group. 2024, Evaluation Script 2.0, SQuAD2.0 The Stanford Question Answering Dataset, viewed 29 March 2024, <https://rajpurkar.github.io/SQuAD-explorer/>.
#
# spaCy. 2024, Trained Pipelines English, viewed 29 March 2024, <https://spacy.io/models/en>
#
# Otmazgin, S., Cattan, A. & Goldberg, Y. 2022, 'F-coref: Fast, Accurate and Easy to Use Coreference Resolution', Proceedings of the AACL

# %% [markdown]
# ## C. Appendix

# %% [markdown]
# ### The threshold for "NO ANSWER" question

# %%
def similarity_threshold(df, questions):
    similarity_list = []

    for i in questions:
        ir_system = Information_Retrieval_System(df, i)
        similarity_list.append(ir_system.similarity)
    
    similarity_avg = sum(similarity_list) / len(similarity_list)

    return similarity_avg

# %%
no_answer_df = self_define_question_df[self_define_question_df["Answer"]=="NO ANSWER"]
no_answer_question = no_answer_df["Question"]

similarity_threshold(df_clean,no_answer_question)
# Out:
# 03/29/2024 12:01:33 - INFO - 	 missing_keys: []
# 03/29/2024 12:01:33 - INFO - 	 unexpected_keys: []
# 03/29/2024 12:01:33 - INFO - 	 mismatched_keys: []
# 03/29/2024 12:01:33 - INFO - 	 error_msgs: []
# 03/29/2024 12:01:33 - INFO - 	 Model Parameters: 90.5M, Transformer: 82.1M, Coref head: 8.4M
# 03/29/2024 12:01:33 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 90.88 examples/s]
# 03/29/2024 12:01:33 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00, 11.88it/s]
# 03/29/2024 12:01:33 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 95.67 examples/s]
# 03/29/2024 12:01:33 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00, 11.94it/s]
# 03/29/2024 12:01:34 - INFO - 	 missing_keys: []
# 03/29/2024 12:01:34 - INFO - 	 unexpected_keys: []
# 03/29/2024 12:01:34 - INFO - 	 mismatched_keys: []
# 03/29/2024 12:01:34 - INFO - 	 error_msgs: []
# 03/29/2024 12:01:34 - INFO - 	 Model Parameters: 90.5M, Transformer: 82.1M, Coref head: 8.4M
# 03/29/2024 12:01:34 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 25.64 examples/s]
# 03/29/2024 12:01:35 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00,  3.74it/s]
# 03/29/2024 12:01:35 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 27.03 examples/s]
# 03/29/2024 12:01:35 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00,  3.67it/s]
# 03/29/2024 12:01:37 - INFO - 	 missing_keys: []
# 03/29/2024 12:01:37 - INFO - 	 unexpected_keys: []
# 03/29/2024 12:01:37 - INFO - 	 mismatched_keys: []
# 03/29/2024 12:01:37 - INFO - 	 error_msgs: []
# 03/29/2024 12:01:37 - INFO - 	 Model Parameters: 90.5M, Transformer: 82.1M, Coref head: 8.4M
# 03/29/2024 12:01:37 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 30.30 examples/s]
# 03/29/2024 12:01:37 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00,  3.14it/s]
# 03/29/2024 12:01:37 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 29.41 examples/s]
# 03/29/2024 12:01:37 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00,  3.61it/s]
# 03/29/2024 12:01:39 - INFO - 	 missing_keys: []
# 03/29/2024 12:01:39 - INFO - 	 unexpected_keys: []
# 03/29/2024 12:01:39 - INFO - 	 mismatched_keys: []
# 03/29/2024 12:01:39 - INFO - 	 error_msgs: []
# 03/29/2024 12:01:39 - INFO - 	 Model Parameters: 90.5M, Transformer: 82.1M, Coref head: 8.4M
# 03/29/2024 12:01:39 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 49.73 examples/s]
# 03/29/2024 12:01:39 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00,  6.23it/s]
# 03/29/2024 12:01:39 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 50.00 examples/s]
# 03/29/2024 12:01:40 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00,  6.40it/s]
# 03/29/2024 12:01:41 - INFO - 	 missing_keys: []
# 03/29/2024 12:01:41 - INFO - 	 unexpected_keys: []
# 03/29/2024 12:01:41 - INFO - 	 mismatched_keys: []
# 03/29/2024 12:01:41 - INFO - 	 error_msgs: []
# 03/29/2024 12:01:41 - INFO - 	 Model Parameters: 90.5M, Transformer: 82.1M, Coref head: 8.4M
# 03/29/2024 12:01:41 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 43.46 examples/s]
# 03/29/2024 12:01:41 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00,  6.63it/s]
# 03/29/2024 12:01:41 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 52.61 examples/s]
# 03/29/2024 12:01:41 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00,  6.63it/s]
# 03/29/2024 12:01:43 - INFO - 	 missing_keys: []
# 03/29/2024 12:01:43 - INFO - 	 unexpected_keys: []
# 03/29/2024 12:01:43 - INFO - 	 mismatched_keys: []
# 03/29/2024 12:01:43 - INFO - 	 error_msgs: []
# 03/29/2024 12:01:43 - INFO - 	 Model Parameters: 90.5M, Transformer: 82.1M, Coref head: 8.4M
# 03/29/2024 12:01:43 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 23.86 examples/s]
# 03/29/2024 12:01:43 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00,  2.93it/s]
# 03/29/2024 12:01:43 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 23.26 examples/s]
# 03/29/2024 12:01:44 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00,  2.94it/s]
# 03/29/2024 12:01:45 - INFO - 	 missing_keys: []
# 03/29/2024 12:01:45 - INFO - 	 unexpected_keys: []
# 03/29/2024 12:01:45 - INFO - 	 mismatched_keys: []
# 03/29/2024 12:01:45 - INFO - 	 error_msgs: []
# 03/29/2024 12:01:45 - INFO - 	 Model Parameters: 90.5M, Transformer: 82.1M, Coref head: 8.4M
# 03/29/2024 12:01:45 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 18.90 examples/s]
# 03/29/2024 12:01:45 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00,  2.62it/s]
# 03/29/2024 12:01:46 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 20.28 examples/s]
# 03/29/2024 12:01:46 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00,  2.65it/s]
# 03/29/2024 12:01:48 - INFO - 	 missing_keys: []
# 03/29/2024 12:01:48 - INFO - 	 unexpected_keys: []
# 03/29/2024 12:01:48 - INFO - 	 mismatched_keys: []
# 03/29/2024 12:01:48 - INFO - 	 error_msgs: []
# 03/29/2024 12:01:48 - INFO - 	 Model Parameters: 90.5M, Transformer: 82.1M, Coref head: 8.4M
# 03/29/2024 12:01:48 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 55.53 examples/s]
# 03/29/2024 12:01:48 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00,  7.88it/s]
# 03/29/2024 12:01:48 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 62.50 examples/s]
# 03/29/2024 12:01:48 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00,  8.10it/s]
# 03/29/2024 12:01:49 - INFO - 	 missing_keys: []
# 03/29/2024 12:01:49 - INFO - 	 unexpected_keys: []
# 03/29/2024 12:01:49 - INFO - 	 mismatched_keys: []
# 03/29/2024 12:01:49 - INFO - 	 error_msgs: []
# 03/29/2024 12:01:49 - INFO - 	 Model Parameters: 90.5M, Transformer: 82.1M, Coref head: 8.4M
# 03/29/2024 12:01:50 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 38.47 examples/s]
# 03/29/2024 12:01:50 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00,  5.23it/s]
# 03/29/2024 12:01:50 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 40.00 examples/s]
# 03/29/2024 12:01:50 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00,  5.17it/s]
# 03/29/2024 12:01:51 - INFO - 	 missing_keys: []
# 03/29/2024 12:01:51 - INFO - 	 unexpected_keys: []
# 03/29/2024 12:01:51 - INFO - 	 mismatched_keys: []
# 03/29/2024 12:01:51 - INFO - 	 error_msgs: []
# 03/29/2024 12:01:51 - INFO - 	 Model Parameters: 90.5M, Transformer: 82.1M, Coref head: 8.4M
# 03/29/2024 12:01:52 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 18.18 examples/s]
# 03/29/2024 12:01:52 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00,  2.09it/s]
# 03/29/2024 12:01:52 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 18.52 examples/s]
# 03/29/2024 12:01:53 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00,  2.07it/s]
# 03/29/2024 12:01:55 - INFO - 	 missing_keys: []
# 03/29/2024 12:01:55 - INFO - 	 unexpected_keys: []
# 03/29/2024 12:01:55 - INFO - 	 mismatched_keys: []
# 03/29/2024 12:01:55 - INFO - 	 error_msgs: []
# 03/29/2024 12:01:55 - INFO - 	 Model Parameters: 90.5M, Transformer: 82.1M, Coref head: 8.4M
# 03/29/2024 12:01:55 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 90.90 examples/s]
# 03/29/2024 12:01:55 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00, 12.40it/s]
# 03/29/2024 12:01:55 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 100.00 examples/s]
# 03/29/2024 12:01:55 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00, 12.04it/s]
# 03/29/2024 12:01:56 - INFO - 	 missing_keys: []
# 03/29/2024 12:01:56 - INFO - 	 unexpected_keys: []
# 03/29/2024 12:01:56 - INFO - 	 mismatched_keys: []
# 03/29/2024 12:01:56 - INFO - 	 error_msgs: []
# 03/29/2024 12:01:56 - INFO - 	 Model Parameters: 90.5M, Transformer: 82.1M, Coref head: 8.4M
# 03/29/2024 12:01:56 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 52.63 examples/s]
# 03/29/2024 12:01:56 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00,  6.72it/s]
# 03/29/2024 12:01:57 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 55.51 examples/s]
# 03/29/2024 12:01:57 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00,  6.74it/s]
# 03/29/2024 12:01:58 - INFO - 	 missing_keys: []
# 03/29/2024 12:01:58 - INFO - 	 unexpected_keys: []
# 03/29/2024 12:01:58 - INFO - 	 mismatched_keys: []
# 03/29/2024 12:01:58 - INFO - 	 error_msgs: []
# 03/29/2024 12:01:58 - INFO - 	 Model Parameters: 90.5M, Transformer: 82.1M, Coref head: 8.4M
# 03/29/2024 12:01:58 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 25.00 examples/s]
# 03/29/2024 12:01:58 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00,  3.23it/s]
# 03/29/2024 12:01:59 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 24.92 examples/s]
# 03/29/2024 12:01:59 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00,  3.21it/s]
# 03/29/2024 12:02:00 - INFO - 	 missing_keys: []
# 03/29/2024 12:02:00 - INFO - 	 unexpected_keys: []
# 03/29/2024 12:02:00 - INFO - 	 mismatched_keys: []
# 03/29/2024 12:02:00 - INFO - 	 error_msgs: []
# 03/29/2024 12:02:00 - INFO - 	 Model Parameters: 90.5M, Transformer: 82.1M, Coref head: 8.4M
# 03/29/2024 12:02:00 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 37.04 examples/s]
# 03/29/2024 12:02:01 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00,  4.26it/s]
# 03/29/2024 12:02:01 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 30.30 examples/s]
# 03/29/2024 12:02:01 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00,  4.88it/s]
# 03/29/2024 12:02:02 - INFO - 	 missing_keys: []
# 03/29/2024 12:02:02 - INFO - 	 unexpected_keys: []
# 03/29/2024 12:02:02 - INFO - 	 mismatched_keys: []
# 03/29/2024 12:02:02 - INFO - 	 error_msgs: []
# 03/29/2024 12:02:02 - INFO - 	 Model Parameters: 90.5M, Transformer: 82.1M, Coref head: 8.4M
# 03/29/2024 12:02:02 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 49.99 examples/s]
# 03/29/2024 12:02:03 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00,  6.11it/s]
# 03/29/2024 12:02:03 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 49.98 examples/s]
# 03/29/2024 12:02:03 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00,  6.12it/s]
# 03/29/2024 12:02:04 - INFO - 	 missing_keys: []
# 03/29/2024 12:02:04 - INFO - 	 unexpected_keys: []
# 03/29/2024 12:02:04 - INFO - 	 mismatched_keys: []
# 03/29/2024 12:02:04 - INFO - 	 error_msgs: []
# 03/29/2024 12:02:04 - INFO - 	 Model Parameters: 90.5M, Transformer: 82.1M, Coref head: 8.4M
# 03/29/2024 12:02:04 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 96.41 examples/s]
# 03/29/2024 12:02:04 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00, 12.42it/s]
# 03/29/2024 12:02:05 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 100.01 examples/s]
# 03/29/2024 12:02:05 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00, 11.76it/s]
# 03/29/2024 12:02:06 - INFO - 	 missing_keys: []
# 03/29/2024 12:02:06 - INFO - 	 unexpected_keys: []
# 03/29/2024 12:02:06 - INFO - 	 mismatched_keys: []
# 03/29/2024 12:02:06 - INFO - 	 error_msgs: []
# 03/29/2024 12:02:06 - INFO - 	 Model Parameters: 90.5M, Transformer: 82.1M, Coref head: 8.4M
# 03/29/2024 12:02:06 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 20.83 examples/s]
# 03/29/2024 12:02:06 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00,  2.59it/s]
# 03/29/2024 12:02:07 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 20.40 examples/s]
# 03/29/2024 12:02:07 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00,  2.62it/s]
# 03/29/2024 12:02:08 - INFO - 	 missing_keys: []
# 03/29/2024 12:02:08 - INFO - 	 unexpected_keys: []
# 03/29/2024 12:02:08 - INFO - 	 mismatched_keys: []
# 03/29/2024 12:02:08 - INFO - 	 error_msgs: []
# 03/29/2024 12:02:08 - INFO - 	 Model Parameters: 90.5M, Transformer: 82.1M, Coref head: 8.4M
# 03/29/2024 12:02:09 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 41.65 examples/s]
# 03/29/2024 12:02:09 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00,  5.53it/s]
# 03/29/2024 12:02:09 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 41.65 examples/s]
# 03/29/2024 12:02:09 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00,  5.68it/s]
# 03/29/2024 12:02:10 - INFO - 	 missing_keys: []
# 03/29/2024 12:02:10 - INFO - 	 unexpected_keys: []
# 03/29/2024 12:02:10 - INFO - 	 mismatched_keys: []
# 03/29/2024 12:02:10 - INFO - 	 error_msgs: []
# 03/29/2024 12:02:10 - INFO - 	 Model Parameters: 90.5M, Transformer: 82.1M, Coref head: 8.4M
# 03/29/2024 12:02:11 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 52.65 examples/s]
# 03/29/2024 12:02:11 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00,  4.79it/s]
# 03/29/2024 12:02:11 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 50.00 examples/s]
# 03/29/2024 12:02:11 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00,  7.12it/s]
# 03/29/2024 12:02:12 - INFO - 	 missing_keys: []
# 03/29/2024 12:02:12 - INFO - 	 unexpected_keys: []
# 03/29/2024 12:02:12 - INFO - 	 mismatched_keys: []
# 03/29/2024 12:02:12 - INFO - 	 error_msgs: []
# 03/29/2024 12:02:12 - INFO - 	 Model Parameters: 90.5M, Transformer: 82.1M, Coref head: 8.4M
# 03/29/2024 12:02:12 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 41.68 examples/s]
# 03/29/2024 12:02:13 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00,  5.72it/s]
# 03/29/2024 12:02:13 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 43.48 examples/s]
# 03/29/2024 12:02:13 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00,  5.64it/s]
# 03/29/2024 12:02:15 - INFO - 	 missing_keys: []
# 03/29/2024 12:02:15 - INFO - 	 unexpected_keys: []
# 03/29/2024 12:02:15 - INFO - 	 mismatched_keys: []
# 03/29/2024 12:02:15 - INFO - 	 error_msgs: []
# 03/29/2024 12:02:15 - INFO - 	 Model Parameters: 90.5M, Transformer: 82.1M, Coref head: 8.4M
# 03/29/2024 12:02:15 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 58.82 examples/s]
# 03/29/2024 12:02:15 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00,  7.95it/s]
# 03/29/2024 12:02:15 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 62.50 examples/s]
# 03/29/2024 12:02:15 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00,  8.06it/s]
# 03/29/2024 12:02:16 - INFO - 	 missing_keys: []
# 03/29/2024 12:02:16 - INFO - 	 unexpected_keys: []
# 03/29/2024 12:02:16 - INFO - 	 mismatched_keys: []
# 03/29/2024 12:02:16 - INFO - 	 error_msgs: []
# 03/29/2024 12:02:16 - INFO - 	 Model Parameters: 90.5M, Transformer: 82.1M, Coref head: 8.4M
# 03/29/2024 12:02:16 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 41.68 examples/s]
# 03/29/2024 12:02:17 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00,  6.47it/s]
# 03/29/2024 12:02:17 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 52.60 examples/s]
# 03/29/2024 12:02:17 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00,  6.51it/s]
# 03/29/2024 12:02:18 - INFO - 	 missing_keys: []
# 03/29/2024 12:02:18 - INFO - 	 unexpected_keys: []
# 03/29/2024 12:02:18 - INFO - 	 mismatched_keys: []
# 03/29/2024 12:02:18 - INFO - 	 error_msgs: []
# 03/29/2024 12:02:18 - INFO - 	 Model Parameters: 90.5M, Transformer: 82.1M, Coref head: 8.4M
# 03/29/2024 12:02:18 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 37.04 examples/s]
# 03/29/2024 12:02:18 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00,  4.60it/s]
# 03/29/2024 12:02:19 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 37.04 examples/s]
# 03/29/2024 12:02:19 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00,  4.52it/s]
# 03/29/2024 12:02:20 - INFO - 	 missing_keys: []
# 03/29/2024 12:02:20 - INFO - 	 unexpected_keys: []
# 03/29/2024 12:02:20 - INFO - 	 mismatched_keys: []
# 03/29/2024 12:02:20 - INFO - 	 error_msgs: []
# 03/29/2024 12:02:20 - INFO - 	 Model Parameters: 90.5M, Transformer: 82.1M, Coref head: 8.4M
# 03/29/2024 12:02:20 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 22.22 examples/s]
# 03/29/2024 12:02:21 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00,  3.14it/s]
# 03/29/2024 12:02:21 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 24.40 examples/s]
# 03/29/2024 12:02:21 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00,  2.63it/s]
# 03/29/2024 12:02:23 - INFO - 	 missing_keys: []
# 03/29/2024 12:02:23 - INFO - 	 unexpected_keys: []
# 03/29/2024 12:02:23 - INFO - 	 mismatched_keys: []
# 03/29/2024 12:02:23 - INFO - 	 error_msgs: []
# 03/29/2024 12:02:23 - INFO - 	 Model Parameters: 90.5M, Transformer: 82.1M, Coref head: 8.4M
# 03/29/2024 12:02:23 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 90.89 examples/s]
# 03/29/2024 12:02:23 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00, 11.90it/s]
# 03/29/2024 12:02:23 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 99.93 examples/s]
# 03/29/2024 12:02:23 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00, 12.38it/s]
# 03/29/2024 12:02:24 - INFO - 	 missing_keys: []
# 03/29/2024 12:02:24 - INFO - 	 unexpected_keys: []
# 03/29/2024 12:02:24 - INFO - 	 mismatched_keys: []
# 03/29/2024 12:02:24 - INFO - 	 error_msgs: []
# 03/29/2024 12:02:24 - INFO - 	 Model Parameters: 90.5M, Transformer: 82.1M, Coref head: 8.4M
# 03/29/2024 12:02:24 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 38.43 examples/s]
# 03/29/2024 12:02:24 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00,  5.37it/s]
# 03/29/2024 12:02:25 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 38.61 examples/s]
# 03/29/2024 12:02:25 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00,  5.23it/s]
# 03/29/2024 12:02:26 - INFO - 	 missing_keys: []
# 03/29/2024 12:02:26 - INFO - 	 unexpected_keys: []
# 03/29/2024 12:02:26 - INFO - 	 mismatched_keys: []
# 03/29/2024 12:02:26 - INFO - 	 error_msgs: []
# 03/29/2024 12:02:26 - INFO - 	 Model Parameters: 90.5M, Transformer: 82.1M, Coref head: 8.4M
# 03/29/2024 12:02:26 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 38.46 examples/s]
# 03/29/2024 12:02:26 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00,  4.84it/s]
# 03/29/2024 12:02:27 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 37.04 examples/s]
# 03/29/2024 12:02:27 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00,  4.68it/s]
# 03/29/2024 12:02:28 - INFO - 	 missing_keys: []
# 03/29/2024 12:02:28 - INFO - 	 unexpected_keys: []
# 03/29/2024 12:02:28 - INFO - 	 mismatched_keys: []
# 03/29/2024 12:02:28 - INFO - 	 error_msgs: []
# 03/29/2024 12:02:28 - INFO - 	 Model Parameters: 90.5M, Transformer: 82.1M, Coref head: 8.4M
# 03/29/2024 12:02:28 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 22.22 examples/s]
# 03/29/2024 12:02:28 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00,  2.68it/s]
# 03/29/2024 12:02:29 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 21.28 examples/s]
# 03/29/2024 12:02:29 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00,  2.74it/s]
# 03/29/2024 12:02:31 - INFO - 	 missing_keys: []
# 03/29/2024 12:02:31 - INFO - 	 unexpected_keys: []
# 03/29/2024 12:02:31 - INFO - 	 mismatched_keys: []
# 03/29/2024 12:02:31 - INFO - 	 error_msgs: []
# 03/29/2024 12:02:31 - INFO - 	 Model Parameters: 90.5M, Transformer: 82.1M, Coref head: 8.4M
# 03/29/2024 12:02:31 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 71.88 examples/s]
# 03/29/2024 12:02:31 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00,  9.48it/s]
# 03/29/2024 12:02:31 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 76.92 examples/s]
# 03/29/2024 12:02:31 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00,  9.75it/s]
# 03/29/2024 12:02:33 - INFO - 	 missing_keys: []
# 03/29/2024 12:02:33 - INFO - 	 unexpected_keys: []
# 03/29/2024 12:02:33 - INFO - 	 mismatched_keys: []
# 03/29/2024 12:02:33 - INFO - 	 error_msgs: []
# 03/29/2024 12:02:33 - INFO - 	 Model Parameters: 90.5M, Transformer: 82.1M, Coref head: 8.4M
# 03/29/2024 12:02:33 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 30.30 examples/s]
# 03/29/2024 12:02:33 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00,  4.28it/s]
# 03/29/2024 12:02:34 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 32.25 examples/s]
# 03/29/2024 12:02:34 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00,  4.48it/s]
# 03/29/2024 12:02:36 - INFO - 	 missing_keys: []
# 03/29/2024 12:02:36 - INFO - 	 unexpected_keys: []
# 03/29/2024 12:02:36 - INFO - 	 mismatched_keys: []
# 03/29/2024 12:02:36 - INFO - 	 error_msgs: []
# 03/29/2024 12:02:36 - INFO - 	 Model Parameters: 90.5M, Transformer: 82.1M, Coref head: 8.4M
# 03/29/2024 12:02:36 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 37.04 examples/s]
# 03/29/2024 12:02:36 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00,  5.04it/s]
# 03/29/2024 12:02:36 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 38.48 examples/s]
# 03/29/2024 12:02:36 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00,  4.94it/s]
# 03/29/2024 12:02:38 - INFO - 	 missing_keys: []
# 03/29/2024 12:02:38 - INFO - 	 unexpected_keys: []
# 03/29/2024 12:02:38 - INFO - 	 mismatched_keys: []
# 03/29/2024 12:02:38 - INFO - 	 error_msgs: []
# 03/29/2024 12:02:38 - INFO - 	 Model Parameters: 90.5M, Transformer: 82.1M, Coref head: 8.4M
# 03/29/2024 12:02:38 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 35.70 examples/s]
# 03/29/2024 12:02:38 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00,  4.43it/s]
# 03/29/2024 12:02:38 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 37.04 examples/s]
# 03/29/2024 12:02:38 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00,  4.91it/s]
# 03/29/2024 12:02:40 - INFO - 	 missing_keys: []
# 03/29/2024 12:02:40 - INFO - 	 unexpected_keys: []
# 03/29/2024 12:02:40 - INFO - 	 mismatched_keys: []
# 03/29/2024 12:02:40 - INFO - 	 error_msgs: []
# 03/29/2024 12:02:40 - INFO - 	 Model Parameters: 90.5M, Transformer: 82.1M, Coref head: 8.4M
# 03/29/2024 12:02:40 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 27.78 examples/s]
# 03/29/2024 12:02:40 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00,  3.78it/s]
# 03/29/2024 12:02:40 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 28.57 examples/s]
# 03/29/2024 12:02:40 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00,  3.79it/s]
# 03/29/2024 12:02:42 - INFO - 	 missing_keys: []
# 03/29/2024 12:02:42 - INFO - 	 unexpected_keys: []
# 03/29/2024 12:02:42 - INFO - 	 mismatched_keys: []
# 03/29/2024 12:02:42 - INFO - 	 error_msgs: []
# 03/29/2024 12:02:42 - INFO - 	 Model Parameters: 90.5M, Transformer: 82.1M, Coref head: 8.4M
# 03/29/2024 12:02:42 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 29.84 examples/s]
# 03/29/2024 12:02:42 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00,  4.12it/s]
# 03/29/2024 12:02:42 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 31.25 examples/s]
# 03/29/2024 12:02:43 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00,  3.97it/s]
# 03/29/2024 12:02:44 - INFO - 	 missing_keys: []
# 03/29/2024 12:02:44 - INFO - 	 unexpected_keys: []
# 03/29/2024 12:02:44 - INFO - 	 mismatched_keys: []
# 03/29/2024 12:02:44 - INFO - 	 error_msgs: []
# 03/29/2024 12:02:44 - INFO - 	 Model Parameters: 90.5M, Transformer: 82.1M, Coref head: 8.4M
# 03/29/2024 12:02:44 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 27.78 examples/s]
# 03/29/2024 12:02:44 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00,  3.69it/s]
# 03/29/2024 12:02:45 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 30.30 examples/s]
# 03/29/2024 12:02:45 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00,  3.57it/s]
# 03/29/2024 12:02:46 - INFO - 	 missing_keys: []
# 03/29/2024 12:02:46 - INFO - 	 unexpected_keys: []
# 03/29/2024 12:02:46 - INFO - 	 mismatched_keys: []
# 03/29/2024 12:02:46 - INFO - 	 error_msgs: []
# 03/29/2024 12:02:46 - INFO - 	 Model Parameters: 90.5M, Transformer: 82.1M, Coref head: 8.4M
# 03/29/2024 12:02:46 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 55.55 examples/s]
# 03/29/2024 12:02:46 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00,  7.28it/s]
# 03/29/2024 12:02:47 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 55.56 examples/s]
# 03/29/2024 12:02:47 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00,  7.00it/s]
# 03/29/2024 12:02:48 - INFO - 	 missing_keys: []
# 03/29/2024 12:02:48 - INFO - 	 unexpected_keys: []
# 03/29/2024 12:02:48 - INFO - 	 mismatched_keys: []
# 03/29/2024 12:02:48 - INFO - 	 error_msgs: []
# 03/29/2024 12:02:48 - INFO - 	 Model Parameters: 90.5M, Transformer: 82.1M, Coref head: 8.4M
# 03/29/2024 12:02:48 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 52.65 examples/s]
# 03/29/2024 12:02:48 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00,  6.56it/s]
# 03/29/2024 12:02:48 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 52.63 examples/s]
# 03/29/2024 12:02:49 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00,  6.75it/s]
# 03/29/2024 12:02:50 - INFO - 	 missing_keys: []
# 03/29/2024 12:02:50 - INFO - 	 unexpected_keys: []
# 03/29/2024 12:02:50 - INFO - 	 mismatched_keys: []
# 03/29/2024 12:02:50 - INFO - 	 error_msgs: []
# 03/29/2024 12:02:50 - INFO - 	 Model Parameters: 90.5M, Transformer: 82.1M, Coref head: 8.4M
# 03/29/2024 12:02:50 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 62.50 examples/s]
# 03/29/2024 12:02:50 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00,  8.47it/s]
# 03/29/2024 12:02:50 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 66.60 examples/s]
# 03/29/2024 12:02:50 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00,  8.25it/s]
# 03/29/2024 12:02:52 - INFO - 	 missing_keys: []
# 03/29/2024 12:02:52 - INFO - 	 unexpected_keys: []
# 03/29/2024 12:02:52 - INFO - 	 mismatched_keys: []
# 03/29/2024 12:02:52 - INFO - 	 error_msgs: []
# 03/29/2024 12:02:52 - INFO - 	 Model Parameters: 90.5M, Transformer: 82.1M, Coref head: 8.4M
# 03/29/2024 12:02:52 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 41.67 examples/s]
# 03/29/2024 12:02:52 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00,  5.73it/s]
# 03/29/2024 12:02:52 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 47.62 examples/s]
# 03/29/2024 12:02:52 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00,  5.84it/s]
# 03/29/2024 12:02:53 - INFO - 	 missing_keys: []
# 03/29/2024 12:02:53 - INFO - 	 unexpected_keys: []
# 03/29/2024 12:02:53 - INFO - 	 mismatched_keys: []
# 03/29/2024 12:02:53 - INFO - 	 error_msgs: []
# 03/29/2024 12:02:53 - INFO - 	 Model Parameters: 90.5M, Transformer: 82.1M, Coref head: 8.4M
# 03/29/2024 12:02:54 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 45.45 examples/s]
# 03/29/2024 12:02:54 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00,  7.14it/s]
# 03/29/2024 12:02:54 - INFO - 	 Tokenize 1 inputs...
# Map: 100%|██████████| 1/1 [00:00<00:00, 47.62 examples/s]
# 03/29/2024 12:02:54 - INFO - 	 ***** Running Inference on 1 texts *****
# Inference: 100%|██████████| 1/1 [00:00<00:00,  6.94it/s]
# 0.31066734131806223
